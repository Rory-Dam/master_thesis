# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('../data/tomato_val_dataset.csv', index_col=0)
dataset
# Out:
#     Overall Liking  Texture liking  Sweetness  Sourness   Salty   Umami  \
# 0           0.3367          0.3406     0.2551    0.1820  0.1294  0.1286
# 1           0.2878          0.2747     0.2556    0.1653  0.1256  0.1667
# 2           0.2701          0.2099     0.2009    0.1710  0.1111  0.1352
# 3           0.2649          0.2119     0.2505    0.1673  0.1153  0.0896
# 4           0.2575          0.2325     0.2440    0.1290  0.1040  0.1019
# ..             ...             ...        ...       ...     ...     ...
# 74          0.0532          0.1300     0.0685    0.0689  0.0647  0.0877
# 75          0.0473          0.0923     0.0831    0.0711  0.0615  0.0812
# 76          0.0453          0.0643     0.1329    0.1183  0.0762  0.0908
# 77          0.0434          0.0631     0.0649    0.2046  0.1077  0.0881
# 78          0.0351          0.0254     0.1354    0.0889  0.0824  0.0962
#
#     Tomato Flavor Intenstity   glucose  fructose  Soluble solids  ...  \
# 0                     0.3341  2.280922  1.913190        2.562857  ...
# 1                     0.3561  0.738719  0.686613        0.719634  ...
# 2                     0.3089  0.027918 -0.164139        0.099564  ...
# 3                     0.3026  2.796207  3.405277        2.928103  ...
# 4                     0.3024  1.215633  1.071788        1.246269  ...
# ..                       ...       ...       ...             ...  ...
# 74                    0.1470 -1.159797 -0.771818       -1.004671  ...
# 75                    0.1462 -0.682884 -0.420299       -0.945212  ...
# 76                    0.2257  0.601675  0.232255        1.823869  ...
# 77                    0.2468 -1.695183 -1.502903       -1.004671  ...
# 78                    0.1910 -1.273087 -1.669314       -0.129777  ...
#
#     citric:malic  3-methyl-1-pentanol  2-ethylfuran  isopentyl acetate  \
# 0       2.510053             1.266061     -0.092380          -1.007032
# 1      -0.582452             1.458910     -0.868766           2.501611
# 2      -0.663188             0.968021      1.149837           0.293926
# 3      -0.247226            -0.609840     -0.247657           1.713152
# 4      -0.508738            -0.013759     -0.713489          -0.928186
# ..           ...                  ...           ...                ...
# 74     -1.108986            -0.925412      1.305114          -0.533956
# 75     -0.961556            -0.557244     -1.179320          -0.218573
# 76      3.649120            -0.820221     -1.645152          -0.888763
# 77      1.388537             1.669292     -0.713489           4.196797
# 78     -1.033516            -0.469585      0.373451          -0.928186
#
#     cis-3-hexenyl acetate  benzothiazole  benzyl alcohol  citric acid  \
# 0                1.312008       1.039829        0.453284     0.923551
# 1                0.512250       1.471306       -0.547379    -1.264632
# 2               -0.335493      -0.055458       -0.070873    -0.613602
# 3               -0.303503      -0.088648       -0.428252     1.945306
# 4               -1.119256       0.309638       -0.213824    -0.215751
# ..                    ...            ...             ...          ...
# 74              -0.943309       0.475591       -0.404427    -1.978956
# 75               0.688197      -0.088648       -0.785631    -1.165169
# 76              -1.631101      -0.254601        2.478433     1.556496
# 77              -0.143551      -0.652887        0.238856     2.768135
# 78              -1.295203       0.176876        0.262681    -0.984327
#
#     3-methyl-2-butenal  p-anisaldehyde
# 0            -0.017934       -0.340967
# 1             0.926590        1.559112
# 2             0.526984       -0.229198
# 3             0.853935       -0.452737
# 4             0.236361       -0.452737
# ..                 ...             ...
# 74           -0.381213        1.670882
# 75           -0.272229       -0.564506
# 76            1.471508        0.106110
# 77            0.236361       -0.340967
# 78           -0.090590        0.217880
#
# [79 rows x 77 columns]

# %%
NUM_LABEL_COLS = 7

# %%
# label_cols = dataset.columns[:NUM_LABEL_COLS]
label_cols = dataset.columns[0]
label_cols
# Out:
# 'Overall Liking'

# %%
feature_cols = dataset.columns[NUM_LABEL_COLS:]
feature_cols
# Out:
# Index(['glucose', 'fructose', 'Soluble solids', '1-penten-3-one',
#        'isovaleronitrile', 'trans-2-pentenal', 'trans-2-heptenal',
#        'trans-3-hexen-1-ol', '6-methyl-5-hepten-2-ol', 'nonyl aldehyde',
#        'cis-4-decenal', 'sugar:acid', 'isovaleraldehyde', '3-methyl-1-butanol',
#        'methional', '2,5-dimethyl-4-hydroxy-3(2H)-furanone', '3-pentanone',
#        '1-pentanol', 'benzyl cyanide', 'isovaleric acid', '2-isobutylthiazole',
#        '1-nitro-3-methylbutane', 'benzaldehyde', '6-methyl-5-hepten-2-one',
#        'b-ionone', 'b-cyclocitral', 'geranial', 'phenylacetaldehyde',
#        'eugenol', 'geranylacetone', '2-phenyl ethanol', 'neral',
#        'salicylaldehyde', 'isobutyl acetate', 'butyl acetate',
#        'cis-3-hexen-1-ol', '1-nitro-2-phenylethane', '1-penten-3-ol',
#        '2-methylbutyl acetate', 'heptaldehyde', 'trans,trans-2,4-decadienal',
#        'malic acid', '2-methylbutanal', '4-carene', 'hexyl alcohol',
#        'guaiacol', 'propyl acetate', 'hexanal', 'cis-2-penten-1-ol',
#        'glutamatic acid', '2-butylacetate', '1-octen-3-one', 'cis-3-hexenal',
#        'methylsalicylate', 'trans-2-hexenal', 'b-damascenone',
#        '2-methyl-1-butanol', '2-methyl-2-butenal', 'prenyl acetate',
#        'hexyl acetate', 'citric:malic', '3-methyl-1-pentanol', '2-ethylfuran',
#        'isopentyl acetate', 'cis-3-hexenyl acetate', 'benzothiazole',
#        'benzyl alcohol', 'citric acid', '3-methyl-2-butenal',
#        'p-anisaldehyde'],
#       dtype='object')

# %%
features = dataset[feature_cols].values
labels = dataset[label_cols].values
print(features.shape)
print(labels.shape)
# Out:
# (79, 70)
# (79,)

# %%
NUM_SAMPLE_TYPES = 54
TEST_SIZE = 0.2
train_X = features[int(NUM_SAMPLE_TYPES*TEST_SIZE):]
train_y = labels[int(NUM_SAMPLE_TYPES*TEST_SIZE):]
test_X = features[:int(NUM_SAMPLE_TYPES*TEST_SIZE)]
test_y = labels[:int(NUM_SAMPLE_TYPES*TEST_SIZE)]

# %%
import xgboost as xgb
from sklearn.metrics import mean_absolute_error as MAE

xgb_regressor = xgb.XGBRegressor(tree_method='hist', objective='reg:tweedie', seed=42)

# Fitting the model
xgb_regressor.fit(train_X, train_y)

# Predict the model
pred = xgb_regressor.predict(test_X)

print("MAE : % f" %(MAE(test_y, pred)))
# Out:
# MAE :  0.106683

# %%
from hyperdt.ensemble import HyperbolicRandomForestRegressor as HyperRF
from sklearn.ensemble import RandomForestRegressor as SklearnRF

# %%
dt_args = {"max_depth": 8, "min_samples_split": 2, "min_samples_leaf": 1}
rf_args = {"n_estimators": 100, **dt_args}

# %%
euc_res = []

for i in range(10):
    np.random.seed(i)
    sklearn_rf = SklearnRF(**rf_args)
    sklearn_rf.fit(train_X, train_y)
    sklearn_rf.score(test_X, test_y)

    pred = sklearn_rf.predict(test_X)
    euc_res.append(MAE(test_y, pred))
    # print("i: %f" %(MAE(test_y, pred)))
print(euc_res)
# Out:
# [0.10407865515873024, 0.10146473535714291, 0.10477692719696981, 0.10418688054511285, 0.10433210376984137, 0.1022937709197325, 0.10349499251686918, 0.10111047803030311, 0.10079614441558449, 0.10282542079710152]

# %%
hyp_res = []

for i in range(10):
    np.random.seed(i)
    hyper_rf = HyperRF(**rf_args)

    for tree in hyper_rf.trees:
        tree.skip_hyperboloid_check = True


    hyper_rf.fit(train_X, train_y)
    hyper_rf.score(test_X, test_y)

    pred = hyper_rf.predict(test_X)
    hyp_res.append(MAE(test_y, pred))
    # print("i: %f" %(MAE(test_y, pred)))
print(hyp_res)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/hyperdt/hyperbolic_trig.py:50: RuntimeWarning: invalid value encountered in sqrt
#   sol = (-v + coef * np.sqrt(v**2 - 4)) / 2
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/hyperdt/hyperbolic_trig.py:50: RuntimeWarning: invalid value encountered in sqrt
#   sol = (-v + coef * np.sqrt(v**2 - 4)) / 2
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/hyperdt/hyperbolic_trig.py:50: RuntimeWarning: invalid value encountered in sqrt
#   sol = (-v + coef * np.sqrt(v**2 - 4)) / 2
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/hyperdt/hyperbolic_trig.py:50: RuntimeWarning: invalid value encountered in sqrt
#   sol = (-v + coef * np.sqrt(v**2 - 4)) / 2
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/hyperdt/hyperbolic_trig.py:50: RuntimeWarning: invalid value encountered in sqrt
#   sol = (-v + coef * np.sqrt(v**2 - 4)) / 2
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/hyperdt/hyperbolic_trig.py:50: RuntimeWarning: invalid value encountered in sqrt
#   sol = (-v + coef * np.sqrt(v**2 - 4)) / 2
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/hyperdt/hyperbolic_trig.py:50: RuntimeWarning: invalid value encountered in sqrt
#   sol = (-v + coef * np.sqrt(v**2 - 4)) / 2
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/hyperdt/hyperbolic_trig.py:50: RuntimeWarning: invalid value encountered in sqrt
#   sol = (-v + coef * np.sqrt(v**2 - 4)) / 2
# [0.11267000000000002, 0.10344000000000006, 0.10533000000000001, 0.08361000000000005, 0.08857000000000001, 0.10547000000000002, 0.08572, 0.09458000000000004, 0.09479000000000004, 0.10050000000000003]

# %%
print(np.median(euc_res))
print(np.median(hyp_res))
# Out:
# 0.10316020665698536
# 0.09764500000000004
