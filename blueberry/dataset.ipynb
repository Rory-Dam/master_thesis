# %%
import numpy as np
import pandas as pd

# %%
raw_mean = pd.read_csv('../data/blueberry_mean.csv')

# %%
drop_cols = ['gID','Year','Location','Harvest#','Genotype','SSC','TA','SSC/TA','Panelists',
             'Total Sugar','Volatile Measures',
             *raw_mean.columns[raw_mean.isna().any()]]
df_mean = raw_mean.drop(columns=drop_cols)
df_mean = df_mean.replace('-', np.nan).astype(float)
df_mean = df_mean.fillna(df_mean.mean())


drop_cols
# Out:
# ['gID',
#  'Year',
#  'Location',
#  'Harvest#',
#  'Genotype',
#  'SSC',
#  'TA',
#  'SSC/TA',
#  'Panelists',
#  'Total Sugar',
#  'Volatile Measures']

# %%
def normalize_column(col):
    return (col - col.mean()) / col.std()

# %%
NUM_LABEL_COLS = 10

# %%
df_mean = df_mean[[*df_mean.columns[1:NUM_LABEL_COLS+1],'pH',*df_mean.columns[NUM_LABEL_COLS+1:]]]
df_mean
# Out:
#      Overall Liking  Texture  Sweetness  Sourness  Flavor  LSOVERALL LIKING  \
# 0              23.5     24.9       22.4      10.7    25.0              23.2
# 1              17.5     25.1       19.2      22.6    27.8              17.2
# 2              24.2     23.9       23.6      11.8    26.5              23.9
# 3              22.3     28.7       21.5      11.2    24.4              22.0
# 4              24.0     23.6       25.5      10.4    25.8              23.7
# ..              ...      ...        ...       ...     ...               ...
# 159            20.5     26.8       22.1      20.6    27.7              19.2
# 160            23.3     25.1       23.2      15.7    25.3              22.1
# 161            29.8     31.0       26.6      13.3    29.1              28.5
# 162            26.4     29.4       25.9      14.6    28.7              25.1
# 163            25.5     20.0       26.3       9.1    26.6              24.2
#
#      LSTEXTURE  LSSWEETNESS  LSSOURNESS  LSFLAVOR  ...  141-27-5  112-12-9  \
# 0         25.4         22.2        10.1      24.6  ...      1.63      0.38
# 1         25.6         18.9        22.1      27.3  ...      1.94      1.39
# 2         24.4         23.4        11.3      26.0  ...      0.52      0.11
# 3         29.2         21.3        10.6      23.9  ...      0.03      0.85
# 4         24.1         25.3         9.8      25.4  ...      1.67      0.05
# ..         ...          ...         ...       ...  ...       ...       ...
# 159       25.0         20.9        20.2      26.1  ...      0.65      0.41
# 160       23.3         22.0        15.2      23.6  ...      0.00      0.80
# 161       29.2         25.5        12.8      27.4  ...      0.00      0.00
# 162       27.6         24.7        14.1      27.0  ...      0.00      0.75
# 163       18.2         25.2         8.6      25.0  ...      0.28      0.00
#
#      629-50-5  3879-26-3  689-67-8  1139-30-6  5989-33-3  43219-68-7  \
# 0        0.11       0.00      2.32       1.78       0.14        1.27
# 1        0.11       0.14      3.30       5.46       1.65        0.66
# 2        0.05       0.00      0.66       2.08       0.15        0.20
# 3        0.09       0.42     14.76       4.74       0.81        1.50
# 4        0.06       0.00      1.52       1.65       0.83        0.41
# ..        ...        ...       ...        ...        ...         ...
# 159      0.00       0.00      0.00       2.26       0.13        0.23
# 160      0.00       0.00      0.98       3.59       0.00        0.12
# 161      0.00       0.00      0.00       2.32       0.13        0.00
# 162      0.00       0.00     11.95       6.02       0.46        0.89
# 163      0.00       0.00      0.00       2.20       1.00        0.00
#
#      564-94-3  582-16-1
# 0         0.0      0.00
# 1         0.0      0.31
# 2         0.0      0.22
# 3         0.0      0.12
# 4         0.0      0.17
# ..        ...       ...
# 159       0.0      0.00
# 160       0.0      0.71
# 161       0.0      0.00
# 162       0.0      0.52
# 163       0.0      0.00
#
# [164 rows x 66 columns]

# %%
val_dataset = df_mean.copy()
val_dataset[val_dataset.columns[:NUM_LABEL_COLS]] = val_dataset[val_dataset.columns[:NUM_LABEL_COLS]] / 100
val_dataset[val_dataset.columns[NUM_LABEL_COLS:]] = val_dataset[val_dataset.columns[NUM_LABEL_COLS:]].apply(normalize_column, axis=0)

# val_dataset.to_csv('../data/blueberry_val_dataset.csv')

# %%
val_dataset
# Out:
#      Overall Liking  Texture  Sweetness  Sourness  Flavor  LSOVERALL LIKING  \
# 0             0.235    0.249      0.224     0.107   0.250             0.232
# 1             0.175    0.251      0.192     0.226   0.278             0.172
# 2             0.242    0.239      0.236     0.118   0.265             0.239
# 3             0.223    0.287      0.215     0.112   0.244             0.220
# 4             0.240    0.236      0.255     0.104   0.258             0.237
# ..              ...      ...        ...       ...     ...               ...
# 159           0.205    0.268      0.221     0.206   0.277             0.192
# 160           0.233    0.251      0.232     0.157   0.253             0.221
# 161           0.298    0.310      0.266     0.133   0.291             0.285
# 162           0.264    0.294      0.259     0.146   0.287             0.251
# 163           0.255    0.200      0.263     0.091   0.266             0.242
#
#      LSTEXTURE  LSSWEETNESS  LSSOURNESS  LSFLAVOR  ...  141-27-5  112-12-9  \
# 0        0.254        0.222       0.101     0.246  ...  2.005649 -0.229453
# 1        0.256        0.189       0.221     0.273  ...  2.599552  1.828292
# 2        0.244        0.234       0.113     0.260  ... -0.120907 -0.779543
# 3        0.292        0.213       0.106     0.239  ... -1.059657  0.728112
# 4        0.241        0.253       0.098     0.254  ...  2.082282 -0.901785
# ..         ...          ...         ...       ...  ...       ...       ...
# 159      0.250        0.209       0.202     0.261  ...  0.128149 -0.168332
# 160      0.233        0.220       0.152     0.236  ... -1.117131  0.626243
# 161      0.292        0.255       0.128     0.274  ... -1.117131 -1.003654
# 162      0.276        0.247       0.141     0.270  ... -1.117131  0.524375
# 163      0.182        0.252       0.086     0.250  ... -0.580703 -1.003654
#
#      629-50-5  3879-26-3  689-67-8  1139-30-6  5989-33-3  43219-68-7  \
# 0    1.415884  -0.423268 -0.066289  -0.644240  -0.520110    1.137106
# 1    1.415884   0.825861  0.209434   1.742866   1.561340    0.272829
# 2    0.204380  -0.423268 -0.533329  -0.449639  -0.506326   -0.378920
# 3    1.012049   3.324119  3.433700   1.275823   0.403447    1.462981
# 4    0.406297  -0.423268 -0.291368  -0.728567   0.431016   -0.081382
# ..        ...        ...       ...        ...        ...         ...
# 159 -0.805207  -0.423268 -0.719020  -0.332879  -0.533895   -0.336415
# 160 -0.805207  -0.423268 -0.443297   0.529853  -0.713093   -0.492268
# 161 -0.805207  -0.423268 -0.719020  -0.293958  -0.533895   -0.662290
# 162 -0.805207  -0.423268  2.643107   2.106121  -0.079008    0.598704
# 163 -0.805207  -0.423268 -0.719020  -0.371799   0.665351   -0.662290
#
#      564-94-3  582-16-1
# 0    -0.20207 -0.732454
# 1    -0.20207  0.865741
# 2    -0.20207  0.401749
# 3    -0.20207 -0.113798
# 4    -0.20207  0.143976
# ..        ...       ...
# 159  -0.20207 -0.732454
# 160  -0.20207  2.927929
# 161  -0.20207 -0.732454
# 162  -0.20207  1.948390
# 163  -0.20207 -0.732454
#
# [164 rows x 66 columns]

# %%
df_samples = pd.DataFrame()
stderr_row = df_mean.var()

# For each row in the original DataFrames
for idx in range(len(df_mean)):
    # Get mean and standard error for the current row
    mean_row = df_mean.iloc[idx]

    # Generate 10 samples from the normal distribution with the mean and standard error
    samples = pd.DataFrame({column: np.random.normal(mean, stderr/20, 10) for column, mean, stderr in zip(df_mean.columns, mean_row, stderr_row)})

    # Append the samples to the new DataFrame
    df_samples = pd.concat([df_samples, samples], ignore_index=True)

df_samples
# Out:
#       Overall Liking    Texture  Sweetness   Sourness     Flavor  \
# 0          21.069550  24.748070  23.081528  10.800855  24.820839
# 1          24.691461  25.753067  22.675508  10.258656  24.542327
# 2          21.469492  24.539381  22.834851  10.091423  25.598065
# 3          21.501150  25.089215  22.788637  11.206361  24.920778
# 4          23.884673  24.978025  22.638774  11.915627  25.407971
# ...              ...        ...        ...        ...        ...
# 1635       26.437076  20.864403  26.172836   8.569664  26.816468
# 1636       24.362005  19.445744  27.555742   8.022170  26.929041
# 1637       27.093423  19.902985  25.788539   7.782133  25.725121
# 1638       25.461960  19.683429  26.384077   9.556149  27.086063
# 1639       25.974617  20.367079  26.861839   9.773830  26.787354
#
#       LSOVERALL LIKING  LSTEXTURE  LSSWEETNESS  LSSOURNESS   LSFLAVOR  ...  \
# 0            24.823411  24.684774    22.824385    9.691979  24.509434  ...
# 1            21.968978  26.197379    22.004035   10.806733  23.950300  ...
# 2            20.984386  24.795929    22.488278   13.461482  24.541562  ...
# 3            23.055667  25.737018    20.906670    8.938175  24.526036  ...
# 4            24.539091  25.228262    22.650280   10.552544  24.706803  ...
# ...                ...        ...          ...         ...        ...  ...
# 1635         23.305045  18.320601    25.545474    9.912754  24.972433  ...
# 1636         24.247286  17.571705    25.305489    9.121445  25.413550  ...
# 1637         24.263127  18.160357    24.758691    8.218572  24.997974  ...
# 1638         23.518867  18.554584    24.715551    7.101558  24.587283  ...
# 1639         24.750169  19.308956    25.733268    5.684252  25.176384  ...
#
#       141-27-5  112-12-9  629-50-5  3879-26-3  689-67-8  1139-30-6  5989-33-3  \
# 0     1.640685  0.383290  0.109852  -0.000314  2.175277   1.601588   0.114188
# 1     1.629409  0.385786  0.110163  -0.000077  2.185173   1.967912   0.116972
# 2     1.644545  0.392138  0.109781   0.000217  3.526192   1.800468   0.139946
# 3     1.645856  0.417981  0.109962  -0.000219  1.673824   1.823491   0.091327
# 4     1.630079  0.382901  0.109903   0.000060  3.492161   1.610853   0.136385
# ...        ...       ...       ...        ...       ...        ...        ...
# 1635  0.285365  0.003155  0.000175   0.000069  0.280842   2.382710   0.966241
# 1636  0.286240  0.005576  0.000149   0.000589 -0.245455   2.237382   0.981802
# 1637  0.283800  0.000372  0.000211   0.000143 -0.614538   2.143128   0.975469
# 1638  0.278013 -0.016665  0.000144  -0.000415 -0.267270   2.079024   1.011885
# 1639  0.289978  0.006641  0.000052  -0.000444  0.350421   2.025850   0.937037
#
#       43219-68-7  564-94-3  582-16-1
# 0       1.265638 -0.000014  0.000402
# 1       1.280241 -0.000024 -0.000983
# 2       1.231934  0.000006  0.001814
# 3       1.253708 -0.000010  0.001294
# 4       1.314349 -0.000001 -0.001483
# ...          ...       ...       ...
# 1635    0.006194  0.000007 -0.002090
# 1636    0.026363  0.000018  0.002067
# 1637    0.031336  0.000004 -0.000310
# 1638   -0.020234  0.000007 -0.000941
# 1639    0.007440  0.000008  0.001798
#
# [1640 rows x 66 columns]

# %%
sample_dataset = df_samples.copy()
sample_dataset[sample_dataset.columns[:NUM_LABEL_COLS]] = sample_dataset[sample_dataset.columns[:NUM_LABEL_COLS]].clip(0) / 100
sample_dataset[sample_dataset.columns[NUM_LABEL_COLS:]] = sample_dataset[sample_dataset.columns[NUM_LABEL_COLS:]].apply(normalize_column, axis=0)

# sample_dataset.to_csv('../data/blueberry_samples_small.csv')
sample_dataset
# Out:
#       Overall Liking   Texture  Sweetness  Sourness    Flavor  \
# 0           0.210695  0.247481   0.230815  0.108009  0.248208
# 1           0.246915  0.257531   0.226755  0.102587  0.245423
# 2           0.214695  0.245394   0.228349  0.100914  0.255981
# 3           0.215011  0.250892   0.227886  0.112064  0.249208
# 4           0.238847  0.249780   0.226388  0.119156  0.254080
# ...              ...       ...        ...       ...       ...
# 1635        0.264371  0.208644   0.261728  0.085697  0.268165
# 1636        0.243620  0.194457   0.275557  0.080222  0.269290
# 1637        0.270934  0.199030   0.257885  0.077821  0.257251
# 1638        0.254620  0.196834   0.263841  0.095561  0.270861
# 1639        0.259746  0.203671   0.268618  0.097738  0.267874
#
#       LSOVERALL LIKING  LSTEXTURE  LSSWEETNESS  LSSOURNESS  LSFLAVOR  ...  \
# 0             0.248234   0.246848     0.228244    0.096920  0.245094  ...
# 1             0.219690   0.261974     0.220040    0.108067  0.239503  ...
# 2             0.209844   0.247959     0.224883    0.134615  0.245416  ...
# 3             0.230557   0.257370     0.209067    0.089382  0.245260  ...
# 4             0.245391   0.252283     0.226503    0.105525  0.247068  ...
# ...                ...        ...          ...         ...       ...  ...
# 1635          0.233050   0.183206     0.255455    0.099128  0.249724  ...
# 1636          0.242473   0.175717     0.253055    0.091214  0.254135  ...
# 1637          0.242631   0.181604     0.247587    0.082186  0.249980  ...
# 1638          0.235189   0.185546     0.247156    0.071016  0.245873  ...
# 1639          0.247502   0.193090     0.257333    0.056843  0.251764  ...
#
#       141-27-5  112-12-9  629-50-5  3879-26-3  689-67-8  1139-30-6  5989-33-3  \
# 0     2.032205 -0.223186  1.416765  -0.427345 -0.104205  -0.761605  -0.556465
# 1     2.010546 -0.218085  1.423052  -0.425223 -0.101455  -0.523638  -0.552621
# 2     2.039621 -0.205103  1.415319  -0.422592  0.271143  -0.632411  -0.520904
# 3     2.042140 -0.152288  1.418986  -0.426496 -0.243532  -0.617455  -0.588025
# 4     2.011831 -0.223981  1.417796  -0.424000  0.261687  -0.755586  -0.525820
# ...        ...       ...       ...        ...       ...        ...        ...
# 1635 -0.571344 -1.000077 -0.803879  -0.423917 -0.630567  -0.254182   0.619848
# 1636 -0.569665 -0.995130 -0.804396  -0.419263 -0.776797  -0.348588   0.641330
# 1637 -0.574352 -1.005765 -0.803130  -0.423257 -0.879345  -0.409816   0.632587
# 1638 -0.585468 -1.040583 -0.804506  -0.428246 -0.782858  -0.451459   0.682862
# 1639 -0.562484 -0.992952 -0.806368  -0.428506 -0.611235  -0.486001   0.579529
#
#       43219-68-7  564-94-3  582-16-1
# 0       1.131805 -0.203557 -0.732237
# 1       1.152505 -0.204223 -0.739394
# 2       1.084029 -0.202227 -0.724940
# 3       1.114894 -0.203298 -0.727629
# 4       1.200853 -0.202689 -0.741981
# ...          ...       ...       ...
# 1635   -0.653468 -0.202169 -0.745115
# 1636   -0.624879 -0.201431 -0.723636
# 1637   -0.617830 -0.202349 -0.735915
# 1638   -0.690931 -0.202114 -0.739178
# 1639   -0.651703 -0.202101 -0.725023
#
# [1640 rows x 66 columns]

# %%
val_dataset = pd.read_csv('../data/blueberry_val_dataset.csv', index_col=0)
sample_dataset = pd.read_csv('../data/blueberry_samples_small.csv', index_col=0)

# %%
sample_dataset
# Out:
#       Overall Liking   Texture  Sweetness  Sourness    Flavor  \
# 0           0.228623  0.243689   0.222702  0.099859  0.251309
# 1           0.255289  0.260470   0.230075  0.110390  0.248659
# 2           0.235173  0.257356   0.229245  0.120068  0.252615
# 3           0.235840  0.248316   0.224748  0.097867  0.255954
# 4           0.232176  0.246991   0.219551  0.128170  0.253716
# ...              ...       ...        ...       ...       ...
# 1635        0.264271  0.197911   0.263882  0.111746  0.267432
# 1636        0.256777  0.193985   0.265818  0.089844  0.268249
# 1637        0.265306  0.197574   0.266302  0.103345  0.268986
# 1638        0.267536  0.200914   0.271609  0.096468  0.262758
# 1639        0.242367  0.203024   0.251101  0.097836  0.272754
#
#       LSOVERALL LIKING  LSTEXTURE  LSSWEETNESS  LSSOURNESS  LSFLAVOR  ...  \
# 0             0.222273   0.260285     0.219207    0.072310  0.243131  ...
# 1             0.233436   0.255153     0.224505    0.112662  0.248409  ...
# 2             0.254171   0.250428     0.223937    0.112505  0.240805  ...
# 3             0.230618   0.249843     0.211105    0.125899  0.242543  ...
# 4             0.236365   0.259706     0.224208    0.074864  0.241443  ...
# ...                ...        ...          ...         ...       ...  ...
# 1635          0.252503   0.180776     0.252096    0.090283  0.251848  ...
# 1636          0.243258   0.177945     0.249265    0.079222  0.249110  ...
# 1637          0.243946   0.179688     0.253402    0.079876  0.256325  ...
# 1638          0.231539   0.185079     0.247726    0.072456  0.248788  ...
# 1639          0.233936   0.184116     0.246655    0.078516  0.244513  ...
#
#       141-27-5  112-12-9  629-50-5  3879-26-3  689-67-8  1139-30-6  5989-33-3  \
# 0     2.016323 -0.229559  1.417900  -0.424658 -0.012040  -0.667972  -0.481286
# 1     2.062154 -0.241523  1.421975  -0.429240 -0.351702  -0.729865  -0.551470
# 2     1.979236 -0.245178  1.420357  -0.418590  0.150889  -0.668821  -0.491247
# 3     2.001802 -0.213714  1.416360  -0.422136  0.217265  -0.617754  -0.459631
# 4     2.040553 -0.260207  1.422129  -0.420362 -0.337685  -0.818532  -0.549779
# ...        ...       ...       ...        ...       ...        ...        ...
# 1635 -0.585980 -0.978985 -0.809325  -0.424482 -0.680218  -0.347446   0.727619
# 1636 -0.585676 -1.029074 -0.803492  -0.426825 -0.831968  -0.569281   0.595218
# 1637 -0.589057 -0.972894 -0.803853  -0.419176 -0.819110  -0.385724   0.644930
# 1638 -0.569256 -0.967632 -0.809824  -0.424932 -0.752979  -0.491467   0.691332
# 1639 -0.547493 -1.042583 -0.808379  -0.436894 -0.717909  -0.315726   0.705631
#
#       43219-68-7  564-94-3  582-16-1
# 0       1.082178 -0.201468 -0.737305
# 1       1.202393 -0.203167 -0.753497
# 2       1.128405 -0.202577 -0.745690
# 3       1.151999 -0.201653 -0.724990
# 4       1.162149 -0.203616 -0.713260
# ...          ...       ...       ...
# 1635   -0.619598 -0.203832 -0.730106
# 1636   -0.671214 -0.202361 -0.745267
# 1637   -0.680441 -0.202733 -0.731297
# 1638   -0.718519 -0.202963 -0.710888
# 1639   -0.653782 -0.203272 -0.735527
#
# [1640 rows x 66 columns]

# %%
avg_1_seed = 54
avg_75_seed = 63
avg_50_seed = 116
avg_25_seed = 132
avg_167_seed = 99
avg_125_seed = 121

# %%
avg_1_indices = val_dataset.sample(frac=1, random_state=avg_1_seed).index
avg_75_indices = val_dataset.sample(frac=3/4, random_state=avg_75_seed).index
avg_50_indices = val_dataset.sample(frac=2/4, random_state=avg_50_seed).index
avg_25_indices = val_dataset.sample(frac=1/4, random_state=avg_25_seed).index
avg_167_indices = val_dataset.sample(frac=1/6, random_state=avg_167_seed).index
avg_125_indices = val_dataset.sample(frac=1/8, random_state=avg_125_seed).index

# %%
print(avg_1_indices)
print(avg_75_indices)
print(avg_50_indices)
print(avg_25_indices)
print(avg_167_indices)
print(avg_125_indices)
# Out:
# Index([ 11,  49, 108,   4,  94,  81,  74,  29,  39, 162,
#        ...
#          9,  17, 135,  56,  64,  23,  15, 130,  69, 111],
#       dtype='int64', length=164)
# Index([123, 156,  52, 145, 150,  79,  59,  94, 158, 151,
#        ...
#         16,  83, 109,   4,  70,  65, 154, 148, 136,  62],
#       dtype='int64', length=123)
# Index([  5, 108,  27,  77,  37, 149,  42,  95, 136, 153, 127,  72,  29,  15,
#         23,  65,  94, 119,  32, 106, 157,  56, 112,  93,  20,  52,  34, 158,
#         62,  84, 125,  97, 104,  48,  43,  68,  47, 109, 155,  16,   9,  71,
#          6,  75,  66,  25,  79, 113,   7,  76, 114,  18, 156, 140,  31, 139,
#        103,  81,  19,  70, 126,   0, 148, 145, 128, 132, 116,  36,  33,  17,
#         38,  35, 121, 137, 101,  57,  98,  40, 133,  24,  64,  50],
#       dtype='int64')
# Index([  9,  54, 107, 154, 147,  68,  60,  55,  23,  35, 100, 158, 128,  45,
#        131, 115,  64, 151,  62, 159,  27,  86,  20, 139,  66,  88,  80, 133,
#          7, 152,  57,  95,  91, 109,   2,  77,  37, 157,  96,  94, 150],
#       dtype='int64')
# Index([ 67, 103, 127, 153,  14,  90,  24,  40,   4, 137,   8,  65,  49, 148,
#        118, 128, 100,  74,  16, 136, 138,  81,  46,   9, 116, 152,  82],
#       dtype='int64')
# Index([147,  45,  92,  91,   6,  72,  85, 127,  50, 101, 123, 110,  98,  24,
#        162, 108,  49, 157,  48,  53],
#       dtype='int64')

# %%
NUM_SAMPLES = len(sample_dataset)//len(val_dataset)
avg_1_sample_indices = np.array([list(range(i*NUM_SAMPLES, (i+1)*NUM_SAMPLES)) for i in avg_1_indices]).flatten()
avg_75_sample_indices = np.array([list(range(i*NUM_SAMPLES, (i+1)*NUM_SAMPLES)) for i in avg_75_indices]).flatten()
avg_50_sample_indices = np.array([list(range(i*NUM_SAMPLES, (i+1)*NUM_SAMPLES)) for i in avg_50_indices]).flatten()
avg_25_sample_indices = np.array([list(range(i*NUM_SAMPLES, (i+1)*NUM_SAMPLES)) for i in avg_25_indices]).flatten()
avg_167_sample_indices = np.array([list(range(i*NUM_SAMPLES, (i+1)*NUM_SAMPLES)) for i in avg_167_indices]).flatten()
avg_125_sample_indices = np.array([list(range(i*NUM_SAMPLES, (i+1)*NUM_SAMPLES)) for i in avg_125_indices]).flatten()

# %%
val_dataset.loc[avg_1_indices].to_csv('../data/blueberry_1_val_dataset.csv')
sample_dataset.loc[avg_1_sample_indices].to_csv('../data/blueberry_1_samples_small.csv')
val_dataset.loc[avg_75_indices].to_csv('../data/blueberry_75_val_dataset.csv')
sample_dataset.loc[avg_75_sample_indices].to_csv('../data/blueberry_75_samples_small.csv')
val_dataset.loc[avg_50_indices].to_csv('../data/blueberry_50_val_dataset.csv')
sample_dataset.loc[avg_50_sample_indices].to_csv('../data/blueberry_50_samples_small.csv')
val_dataset.loc[avg_25_indices].to_csv('../data/blueberry_25_val_dataset.csv')
sample_dataset.loc[avg_25_sample_indices].to_csv('../data/blueberry_25_samples_small.csv')
val_dataset.loc[avg_167_indices].to_csv('../data/blueberry_167_val_dataset.csv')
sample_dataset.loc[avg_167_sample_indices].to_csv('../data/blueberry_167_samples_small.csv')
val_dataset.loc[avg_125_indices].to_csv('../data/blueberry_125_val_dataset.csv')
sample_dataset.loc[avg_125_sample_indices].to_csv('../data/blueberry_125_samples_small.csv')
