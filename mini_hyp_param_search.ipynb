# %%
import numpy as np
import pandas as pd

# %%
import consts
import util

# %%
dataset = pd.read_csv('data/arc_mini_comb_red.csv', index_col=0)

possible_target_cols = np.array(['Floral', 'Fruity', 'Woody', 'Odourless'])
# target_cols = consts.TARGET_COLS
target_cols = possible_target_cols

# feature_cols = dataset.columns[possible_target_cols.shape[0]:]
feature_cols = dataset.columns[possible_target_cols.shape[0]:possible_target_cols.shape[0]+326]
feature_cols

features = dataset[feature_cols].apply(util.normalize_column, axis=0).fillna(0).values
labels = dataset[target_cols].values

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset

from hypll import nn as hnn
from hypll.tensors import TangentTensor

# Define your MLP model
class MLP(nn.Module):
    def __init__(self, input_size, output_size, layer_size, num_hidden_layers, manifold):
        super(MLP, self).__init__()
        torch.manual_seed(consts.TORCH_MANUAL_SEED)
        self.fc_in = hnn.HLinear(input_size, layer_size, manifold=manifold)
        self.relu = hnn.HReLU(manifold=manifold)
        self.hidden_fcs = nn.ModuleList([hnn.HLinear(layer_size, layer_size, manifold=manifold) for _ in range(num_hidden_layers)])
        self.fc_out = hnn.HLinear(layer_size, output_size, manifold=manifold)

    def forward(self, x):
        x = self.fc_in(x)
        x = self.relu(x)
        for fc in self.hidden_fcs:
            x = fc(x)
            x = self.relu(x)
        x = self.fc_out(x)
        x = F.softmax(x.tensor, dim=1)
        return x

# Define custom PyTorch dataset
class CustomDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.float32)

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# Define training function
def train_model(model, train_loader, criterion, optimizer, manifold, device):
    model.train()
    running_loss = 0.0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        tangents = TangentTensor(data=inputs, man_dim=-1, manifold=manifold)
        manifold_inputs = manifold.expmap(tangents)

        outputs = model(manifold_inputs)

        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    return running_loss / len(train_loader.dataset)

# %%
param_grid = {'num_hidden_layers': [0,1,2],
              'layer_size': [64, 128],
              'lr': [0.001, 0.002, 0.003],
              'weight_decay': [0.001, 0.005, 0.01],
              'batch_size': [32, 48, 64, 80, 96],
              'BCE_weights_power': [0.5],
              'BCE_weights_factor': [1.2],
              'epochs': [20],
              'curvature': [-1]}

best_grid = {'num_hidden_layers': [0],
              'layer_size': [128],
              'lr': [0.003],
              'weight_decay': [0.01],
              'batch_size': [96],
              'BCE_weights_power': [0.5],
              'BCE_weights_factor': [1.2],
              'epochs': [20],
              'curvature': [-1]}
# 0.002, 48
# 0.003, 96+



np.prod([len(p) for p in param_grid.values()])
# Out:
# 270

# %%
import itertools
param_combinations = list(itertools.product(*param_grid.values()))

# %%
combination_stats = {params: [] for params in param_combinations}

# %%
from hypll.manifolds.poincare_ball import Curvature, PoincareBall

from hypll.optim import RiemannianAdam
from torch.utils.data import DataLoader
from sklearn.model_selection import KFold
from tqdm.notebook import tqdm

for i, params in enumerate(param_combinations):
    print(f'----- Combination {i} -----')
    print(*zip(param_grid.keys(), params))
    num_hidden_layers, layer_size, lr, weight_decay, batch_size, BCE_weights_power, BCE_weights_factor, epochs, curvature = params

    manifold = PoincareBall(c=Curvature(curvature))

    METRICS = ['acc', 'hamm', 'prec', 'sens', 'f1', 'aps']

    eval_stats = {'loss': {'train': [], 'val': []}}
    for metric in METRICS:
        eval_stats[metric] = {'train': [],
                            'val': []}

    # Initialize cross-validation
    kf = KFold(n_splits=consts.KFOLDS, shuffle=True, random_state=consts.KFOLD_SEED)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Create an empty list to store parameters
    all_model_params = []
    # Cross-validation loop
    for fold, (train_idx, val_idx) in enumerate(kf.split(features, labels)):
        print(f'Fold {fold + 1}')

        # Split data into train and validation sets
        train_features, val_features = features[train_idx], features[val_idx]
        train_labels, val_labels = labels[train_idx], labels[val_idx]

        # Create DataLoader for training and validation
        train_dataset = CustomDataset(train_features, train_labels)
        val_dataset = CustomDataset(val_features, val_labels)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=batch_size)

        # Initialize model, criterion, and optimizer
        model = MLP(input_size=len(feature_cols), output_size=len(target_cols), layer_size=layer_size, num_hidden_layers=num_hidden_layers, manifold=manifold).to(device)
        # criterion = nn.BCELoss()

        possible_label_occurences = torch.tensor(dataset[possible_target_cols].mean())
        indices = np.where(np.isin(possible_target_cols, target_cols))[0]
        label_occurences = possible_label_occurences[indices]

        bce_positive_weights = util.calc_bce_positive_weights(label_occurences, BCE_weights_power, BCE_weights_factor)

        criterion = nn.BCEWithLogitsLoss(pos_weight=bce_positive_weights)

        optimizer = RiemannianAdam(model.parameters(), lr=lr, weight_decay=weight_decay)

        # Training loop
        eval_stats_fold = {'loss': {'train': [], 'val': []}}
        for metric in METRICS:
            eval_stats_fold[metric] = {'train': [],
                                        'val': []}

        for epoch in range(epochs):
            eval_stats_fold['loss']['train'].append(train_model(model, train_loader, criterion, optimizer, manifold, device))
            eval_stats_fold['loss']['val'].append(util.h_mini_evaluate_loss(model, val_loader, criterion, manifold, device))

            # Calculate and store specuracy
            # accuracy, hamm, precision, sensitivity, f1, aps
            eval_train = util.h_mini_evaluate_metrics(model, train_loader, manifold, device)
            eval_val = util.h_mini_evaluate_metrics(model, val_loader, manifold, device)
            for i, metric in enumerate(METRICS):
                eval_stats_fold[metric]['train'].append(eval_train[i])
                eval_stats_fold[metric]['val'].append(eval_val[i])

            # print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {eval_stats_fold['loss']['train'][-1]:.4f}, Val Loss: {eval_stats_fold['loss']['val'][-1]:.4f}")

        for metric in METRICS:
            stat = eval_stats_fold[metric]['val'][-1]
            if type(stat) == np.ndarray:
                stat = list(stat)

            print(f'{metric}:\t', stat)

        eval_stats['loss']['train'].append(eval_stats_fold['loss']['train'])
        eval_stats['loss']['val'].append(eval_stats_fold['loss']['val'])
        for metric in METRICS:
            eval_stats[metric]['train'].append(eval_stats_fold[metric]['train'])
            eval_stats[metric]['val'].append(eval_stats_fold[metric]['val'])
# Out:
# ----- Combination 0 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.001) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.592391304347826
# hamm:	 0.20380434782608695
# prec:	 0.592391304347826
# sens:	 0.592391304347826
# f1:	 0.592391304347826
# aps:	 [0.5780179747615695, 0.6842870969698117, 0.6171819795399283, 0.5302662152649852]
# Fold 2
# acc:	 0.6267029972752044
# hamm:	 0.18664850136239783
# prec:	 0.6267029972752044
# sens:	 0.6267029972752044
# f1:	 0.6267029972752044
# aps:	 [0.6416219380667229, 0.7788137080490831, 0.6186980852070558, 0.6335301285641048]
# Fold 3
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.6013726664554953, 0.7045580013733101, 0.5370032778816403, 0.44292952146419673]
# Fold 4
# acc:	 0.5994550408719346
# hamm:	 0.20027247956403268
# prec:	 0.5994550408719346
# sens:	 0.5994550408719346
# f1:	 0.5994550408719346
# aps:	 [0.6126783670660919, 0.6930627702903933, 0.5488593960902554, 0.5567085640332589]
# Fold 5
# acc:	 0.5940054495912807
# hamm:	 0.20299727520435967
# prec:	 0.5940054495912807
# sens:	 0.5940054495912807
# f1:	 0.5940054495912807
# aps:	 [0.5819271674002134, 0.6907746898462414, 0.4679307867168539, 0.5432202162504441]
# ----- Combination 1 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.001) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5788043478260869
# hamm:	 0.2105978260869565
# prec:	 0.5788043478260869
# sens:	 0.5788043478260869
# f1:	 0.5788043478260869
# aps:	 [0.570774823361005, 0.6796433841713534, 0.6135933704518497, 0.5249172865913017]
# Fold 2
# acc:	 0.6049046321525886
# hamm:	 0.19754768392370572
# prec:	 0.6049046321525886
# sens:	 0.6049046321525886
# f1:	 0.6049046321525886
# aps:	 [0.6360055588722485, 0.7765924997039032, 0.6200451628732374, 0.6330068919760528]
# Fold 3
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.5872975756385705, 0.6944835905698934, 0.5174340711035373, 0.4462432666471425]
# Fold 4
# acc:	 0.55858310626703
# hamm:	 0.22070844686648503
# prec:	 0.55858310626703
# sens:	 0.55858310626703
# f1:	 0.55858310626703
# aps:	 [0.5985156180691779, 0.6922827183581117, 0.5500116652402677, 0.5460273701915843]
# Fold 5
# acc:	 0.5776566757493188
# hamm:	 0.2111716621253406
# prec:	 0.5776566757493188
# sens:	 0.5776566757493188
# f1:	 0.5776566757493188
# aps:	 [0.5803956575596108, 0.6919424356407428, 0.46576282625324683, 0.5380626494804559]
# ----- Combination 2 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.001) ('batch_size', 64) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5679347826086957
# hamm:	 0.21603260869565216
# prec:	 0.5679347826086957
# sens:	 0.5679347826086957
# f1:	 0.5679347826086957
# aps:	 [0.5572487629530927, 0.674255023523294, 0.6124386880702704, 0.5150568031359768]
# Fold 2
# acc:	 0.5885558583106267
# hamm:	 0.20572207084468666
# prec:	 0.5885558583106267
# sens:	 0.5885558583106267
# f1:	 0.5885558583106267
# aps:	 [0.6293315899932094, 0.7695256981043958, 0.6172394884049639, 0.6242756320534623]
# Fold 3
# acc:	 0.5694822888283378
# hamm:	 0.21525885558583105
# prec:	 0.5694822888283378
# sens:	 0.5694822888283378
# f1:	 0.5694822888283378
# aps:	 [0.5899042068120607, 0.6926484714385868, 0.5095273239506112, 0.4509921217920073]
# Fold 4
# acc:	 0.5722070844686649
# hamm:	 0.21389645776566757
# prec:	 0.5722070844686649
# sens:	 0.5722070844686649
# f1:	 0.5722070844686649
# aps:	 [0.6042659540972966, 0.6950258379061022, 0.5584650390018796, 0.5536347112339096]
# Fold 5
# acc:	 0.5831062670299727
# hamm:	 0.20844686648501362
# prec:	 0.5831062670299727
# sens:	 0.5831062670299727
# f1:	 0.5831062670299727
# aps:	 [0.572664300115427, 0.6794224364785612, 0.45602859978816473, 0.5380591031267726]
# ----- Combination 3 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.001) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5570652173913043
# hamm:	 0.22146739130434784
# prec:	 0.5570652173913043
# sens:	 0.5570652173913043
# f1:	 0.5570652173913043
# aps:	 [0.5680276141346201, 0.6825510034751417, 0.6064466855980613, 0.522654759197483]
# Fold 2
# acc:	 0.5967302452316077
# hamm:	 0.2016348773841962
# prec:	 0.5967302452316077
# sens:	 0.5967302452316077
# f1:	 0.5967302452316077
# aps:	 [0.6154012812482366, 0.7733763537228526, 0.6290467967231294, 0.6217471184407292]
# Fold 3
# acc:	 0.555858310626703
# hamm:	 0.2220708446866485
# prec:	 0.555858310626703
# sens:	 0.555858310626703
# f1:	 0.555858310626703
# aps:	 [0.5904224011087928, 0.6740502668717951, 0.5159551120519595, 0.44074992040620553]
# Fold 4
# acc:	 0.5640326975476839
# hamm:	 0.21798365122615804
# prec:	 0.5640326975476839
# sens:	 0.5640326975476839
# f1:	 0.5640326975476839
# aps:	 [0.5923788098483654, 0.6914197906224462, 0.5389940517154214, 0.5524158128517845]
# Fold 5
# acc:	 0.5613079019073569
# hamm:	 0.21934604904632152
# prec:	 0.5613079019073569
# sens:	 0.5613079019073569
# f1:	 0.5613079019073569
# aps:	 [0.5661975363245446, 0.6783757023119563, 0.4703182713680346, 0.5326008719030397]
# ----- Combination 4 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.001) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5570652173913043
# hamm:	 0.22146739130434784
# prec:	 0.5570652173913043
# sens:	 0.5570652173913043
# f1:	 0.5570652173913043
# aps:	 [0.5669677579701569, 0.6753843445122485, 0.61130975410792, 0.5236788818619275]
# Fold 2
# acc:	 0.5912806539509536
# hamm:	 0.20435967302452315
# prec:	 0.5912806539509536
# sens:	 0.5912806539509536
# f1:	 0.5912806539509536
# aps:	 [0.611585267394756, 0.7738239219997114, 0.6228444953157506, 0.6155689630615456]
# Fold 3
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.5891273378049717, 0.6705834130198417, 0.5173681369075138, 0.4456857570140238]
# Fold 4
# acc:	 0.55858310626703
# hamm:	 0.22070844686648503
# prec:	 0.55858310626703
# sens:	 0.55858310626703
# f1:	 0.55858310626703
# aps:	 [0.5807739591086787, 0.6943279764829099, 0.5471579522836028, 0.54966314037338]
# Fold 5
# acc:	 0.5667574931880109
# hamm:	 0.21662125340599456
# prec:	 0.5667574931880109
# sens:	 0.5667574931880109
# f1:	 0.5667574931880109
# aps:	 [0.5642804105909716, 0.6728947630063447, 0.48369148597456707, 0.5376135755560174]
# ----- Combination 5 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.005) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5896739130434783
# hamm:	 0.20516304347826086
# prec:	 0.5896739130434783
# sens:	 0.5896739130434783
# f1:	 0.5896739130434783
# aps:	 [0.583996700595755, 0.6918086197257196, 0.6172236260347693, 0.5234616366526871]
# Fold 2
# acc:	 0.6185286103542235
# hamm:	 0.1907356948228883
# prec:	 0.6185286103542235
# sens:	 0.6185286103542235
# f1:	 0.6185286103542235
# aps:	 [0.6530738848738621, 0.7811091086305879, 0.6169251070305294, 0.6300336513578974]
# Fold 3
# acc:	 0.5422343324250681
# hamm:	 0.22888283378746593
# prec:	 0.5422343324250681
# sens:	 0.5422343324250681
# f1:	 0.5422343324250681
# aps:	 [0.5996836604398389, 0.7050912993926217, 0.5261942582032251, 0.4454270936781495]
# Fold 4
# acc:	 0.5885558583106267
# hamm:	 0.20572207084468666
# prec:	 0.5885558583106267
# sens:	 0.5885558583106267
# f1:	 0.5885558583106267
# aps:	 [0.6063100303732651, 0.6846524499634299, 0.54989660273487, 0.5603117868404822]
# Fold 5
# acc:	 0.5940054495912807
# hamm:	 0.20299727520435967
# prec:	 0.5940054495912807
# sens:	 0.5940054495912807
# f1:	 0.5940054495912807
# aps:	 [0.5795871892820867, 0.697934161949524, 0.4666639681845726, 0.5397612897113564]
# ----- Combination 6 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.005) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5788043478260869
# hamm:	 0.2105978260869565
# prec:	 0.5788043478260869
# sens:	 0.5788043478260869
# f1:	 0.5788043478260869
# aps:	 [0.5792388612032593, 0.682942569861584, 0.610145897146433, 0.5288423097092062]
# Fold 2
# acc:	 0.6021798365122616
# hamm:	 0.1989100817438692
# prec:	 0.6021798365122616
# sens:	 0.6021798365122616
# f1:	 0.6021798365122616
# aps:	 [0.6324821686200791, 0.7800441556475997, 0.6197614309267573, 0.6357986809175697]
# Fold 3
# acc:	 0.555858310626703
# hamm:	 0.2220708446866485
# prec:	 0.555858310626703
# sens:	 0.555858310626703
# f1:	 0.555858310626703
# aps:	 [0.5885550325806077, 0.6934660991128319, 0.5223708145094137, 0.4493273937805542]
# Fold 4
# acc:	 0.5776566757493188
# hamm:	 0.2111716621253406
# prec:	 0.5776566757493188
# sens:	 0.5776566757493188
# f1:	 0.5776566757493188
# aps:	 [0.5985738365646509, 0.6965027211285474, 0.5493043702961059, 0.5573502107012978]
# Fold 5
# acc:	 0.5749318801089919
# hamm:	 0.2125340599455041
# prec:	 0.5749318801089919
# sens:	 0.5749318801089919
# f1:	 0.5749318801089919
# aps:	 [0.5785278050797716, 0.689783036947673, 0.4510100341019249, 0.5393866345603271]
# ----- Combination 7 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.005) ('batch_size', 64) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5597826086956522
# hamm:	 0.22010869565217392
# prec:	 0.5597826086956522
# sens:	 0.5597826086956522
# f1:	 0.5597826086956522
# aps:	 [0.557150823276779, 0.6798933384270737, 0.60984050173912, 0.5186685422445149]
# Fold 2
# acc:	 0.5994550408719346
# hamm:	 0.20027247956403268
# prec:	 0.5994550408719346
# sens:	 0.5994550408719346
# f1:	 0.5994550408719346
# aps:	 [0.6276409205069667, 0.7750212950902243, 0.6221105905746616, 0.6217619575986642]
# Fold 3
# acc:	 0.5640326975476839
# hamm:	 0.21798365122615804
# prec:	 0.5640326975476839
# sens:	 0.5640326975476839
# f1:	 0.5640326975476839
# aps:	 [0.5962208770453932, 0.6939947150983158, 0.5071839847987183, 0.45128302240194074]
# Fold 4
# acc:	 0.5749318801089919
# hamm:	 0.2125340599455041
# prec:	 0.5749318801089919
# sens:	 0.5749318801089919
# f1:	 0.5749318801089919
# aps:	 [0.6095347126328214, 0.7019035342079677, 0.5448593656841559, 0.5563433837717651]
# Fold 5
# acc:	 0.5722070844686649
# hamm:	 0.21389645776566757
# prec:	 0.5722070844686649
# sens:	 0.5722070844686649
# f1:	 0.5722070844686649
# aps:	 [0.5777931161800142, 0.6792510587276646, 0.45514211838664925, 0.5380163327979594]
# ----- Combination 8 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.005) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5652173913043478
# hamm:	 0.21739130434782608
# prec:	 0.5652173913043478
# sens:	 0.5652173913043478
# f1:	 0.5652173913043478
# aps:	 [0.562470307493967, 0.6813582796774539, 0.6101153430780983, 0.5149194584031644]
# Fold 2
# acc:	 0.5994550408719346
# hamm:	 0.20027247956403268
# prec:	 0.5994550408719346
# sens:	 0.5994550408719346
# f1:	 0.5994550408719346
# aps:	 [0.609979579212794, 0.7719259503252182, 0.6285829664089042, 0.6205617523470568]
# Fold 3
# acc:	 0.5640326975476839
# hamm:	 0.21798365122615804
# prec:	 0.5640326975476839
# sens:	 0.5640326975476839
# f1:	 0.5640326975476839
# aps:	 [0.5928901101010032, 0.6713131028651871, 0.5176831826942212, 0.438065583859859]
# Fold 4
# acc:	 0.5640326975476839
# hamm:	 0.21798365122615804
# prec:	 0.5640326975476839
# sens:	 0.5640326975476839
# f1:	 0.5640326975476839
# aps:	 [0.5855276145228824, 0.6950926360228493, 0.5441413452206084, 0.5557919507264419]
# Fold 5
# acc:	 0.5722070844686649
# hamm:	 0.21389645776566757
# prec:	 0.5722070844686649
# sens:	 0.5722070844686649
# f1:	 0.5722070844686649
# aps:	 [0.5666385435815902, 0.6813688241014538, 0.47327580912011286, 0.5339893955098086]
# ----- Combination 9 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.005) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5733695652173914
# hamm:	 0.21331521739130435
# prec:	 0.5733695652173914
# sens:	 0.5733695652173914
# f1:	 0.5733695652173914
# aps:	 [0.5650668990539952, 0.6791886819578038, 0.6134765057332392, 0.5222750281919504]
# Fold 2
# acc:	 0.5912806539509536
# hamm:	 0.20435967302452315
# prec:	 0.5912806539509536
# sens:	 0.5912806539509536
# f1:	 0.5912806539509536
# aps:	 [0.6136932919327337, 0.7738933088491612, 0.6183564851914867, 0.6175360909267336]
# Fold 3
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.5893890202922563, 0.6817873212261388, 0.5179025514696977, 0.4466220008324062]
# Fold 4
# acc:	 0.5613079019073569
# hamm:	 0.21934604904632152
# prec:	 0.5613079019073569
# sens:	 0.5613079019073569
# f1:	 0.5613079019073569
# aps:	 [0.580582721769234, 0.6973892420534075, 0.5433493840696983, 0.550774120164063]
# Fold 5
# acc:	 0.5722070844686649
# hamm:	 0.21389645776566757
# prec:	 0.5722070844686649
# sens:	 0.5722070844686649
# f1:	 0.5722070844686649
# aps:	 [0.5633131179608197, 0.6729340162700032, 0.4902092081281067, 0.5355299686961313]
# ----- Combination 10 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.01) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5815217391304348
# hamm:	 0.20923913043478262
# prec:	 0.5815217391304348
# sens:	 0.5815217391304348
# f1:	 0.5815217391304348
# aps:	 [0.5743444484471075, 0.6864138156181442, 0.6239465180125772, 0.5216174064359572]
# Fold 2
# acc:	 0.6130790190735694
# hamm:	 0.19346049046321526
# prec:	 0.6130790190735694
# sens:	 0.6130790190735694
# f1:	 0.6130790190735694
# aps:	 [0.6426276430578978, 0.7839235884019751, 0.6212629487726328, 0.6257176394260869]
# Fold 3
# acc:	 0.5422343324250681
# hamm:	 0.22888283378746593
# prec:	 0.5422343324250681
# sens:	 0.5422343324250681
# f1:	 0.5422343324250681
# aps:	 [0.5891804353228755, 0.7088253410859836, 0.533101137082182, 0.4458714026399253]
# Fold 4
# acc:	 0.5967302452316077
# hamm:	 0.2016348773841962
# prec:	 0.5967302452316077
# sens:	 0.5967302452316077
# f1:	 0.5967302452316077
# aps:	 [0.6111023484361123, 0.6873180180872076, 0.5422687671789043, 0.5475580666545746]
# Fold 5
# acc:	 0.5940054495912807
# hamm:	 0.20299727520435967
# prec:	 0.5940054495912807
# sens:	 0.5940054495912807
# f1:	 0.5940054495912807
# aps:	 [0.5863656973483109, 0.6973849180930246, 0.46248848564975875, 0.5430373969250014]
# ----- Combination 11 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.01) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5706521739130435
# hamm:	 0.21467391304347827
# prec:	 0.5706521739130435
# sens:	 0.5706521739130435
# f1:	 0.5706521739130435
# aps:	 [0.5686998267498631, 0.6836183519910105, 0.6097504986072135, 0.5222399572185142]
# Fold 2
# acc:	 0.6021798365122616
# hamm:	 0.1989100817438692
# prec:	 0.6021798365122616
# sens:	 0.6021798365122616
# f1:	 0.6021798365122616
# aps:	 [0.6277834828246267, 0.7789980491226731, 0.6213378142864762, 0.6312833796524153]
# Fold 3
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.5894759926101324, 0.6906793038461334, 0.5210965237604996, 0.4471578368280443]
# Fold 4
# acc:	 0.5803814713896458
# hamm:	 0.2098092643051771
# prec:	 0.5803814713896458
# sens:	 0.5803814713896458
# f1:	 0.5803814713896458
# aps:	 [0.6054572590909038, 0.6914762810697207, 0.5528309143695351, 0.5560394078414967]
# Fold 5
# acc:	 0.5667574931880109
# hamm:	 0.21662125340599456
# prec:	 0.5667574931880109
# sens:	 0.5667574931880109
# f1:	 0.5667574931880109
# aps:	 [0.5794508806402187, 0.6888681357888273, 0.462222003305282, 0.5383326842051261]
# ----- Combination 12 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.01) ('batch_size', 64) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5625
# hamm:	 0.21875
# prec:	 0.5625
# sens:	 0.5625
# f1:	 0.5625
# aps:	 [0.5674327034031514, 0.676444717863595, 0.6087603681013993, 0.5176435931349679]
# Fold 2
# acc:	 0.5940054495912807
# hamm:	 0.20299727520435967
# prec:	 0.5940054495912807
# sens:	 0.5940054495912807
# f1:	 0.5940054495912807
# aps:	 [0.6273457090838717, 0.7722077380032981, 0.6202590594450301, 0.6243363560985652]
# Fold 3
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.5875759960545222, 0.6946419950030378, 0.5130840012509454, 0.45030139183667384]
# Fold 4
# acc:	 0.5749318801089919
# hamm:	 0.2125340599455041
# prec:	 0.5749318801089919
# sens:	 0.5749318801089919
# f1:	 0.5749318801089919
# aps:	 [0.6039217511647502, 0.692651453205118, 0.5482721852370004, 0.5547998906418603]
# Fold 5
# acc:	 0.5803814713896458
# hamm:	 0.2098092643051771
# prec:	 0.5803814713896458
# sens:	 0.5803814713896458
# f1:	 0.5803814713896458
# aps:	 [0.57318570677355, 0.6791138809946635, 0.45286160052398006, 0.5351987009562971]
# ----- Combination 13 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.01) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5652173913043478
# hamm:	 0.21739130434782608
# prec:	 0.5652173913043478
# sens:	 0.5652173913043478
# f1:	 0.5652173913043478
# aps:	 [0.5627446711366825, 0.6797749451108706, 0.6140214570545841, 0.5193825925027704]
# Fold 2
# acc:	 0.5940054495912807
# hamm:	 0.20299727520435967
# prec:	 0.5940054495912807
# sens:	 0.5940054495912807
# f1:	 0.5940054495912807
# aps:	 [0.6189687452782142, 0.7744744966604123, 0.6219123936358928, 0.6197361716525343]
# Fold 3
# acc:	 0.547683923705722
# hamm:	 0.22615803814713897
# prec:	 0.547683923705722
# sens:	 0.547683923705722
# f1:	 0.547683923705722
# aps:	 [0.5860018855342365, 0.6755379346413345, 0.5192209931180126, 0.4403785523926364]
# Fold 4
# acc:	 0.5667574931880109
# hamm:	 0.21662125340599456
# prec:	 0.5667574931880109
# sens:	 0.5667574931880109
# f1:	 0.5667574931880109
# aps:	 [0.5953613996551456, 0.6935921370571606, 0.5539835920172073, 0.5542184255064521]
# Fold 5
# acc:	 0.5613079019073569
# hamm:	 0.21934604904632152
# prec:	 0.5613079019073569
# sens:	 0.5613079019073569
# f1:	 0.5613079019073569
# aps:	 [0.5694583311756287, 0.6812587842125998, 0.4614103771391575, 0.5357131200814973]
# ----- Combination 14 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.001) ('weight_decay', 0.01) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5679347826086957
# hamm:	 0.21603260869565216
# prec:	 0.5679347826086957
# sens:	 0.5679347826086957
# f1:	 0.5679347826086957
# aps:	 [0.5647146339987258, 0.6697548460461072, 0.6055400414535539, 0.5178918313337836]
# Fold 2
# acc:	 0.5912806539509536
# hamm:	 0.20435967302452315
# prec:	 0.5912806539509536
# sens:	 0.5912806539509536
# f1:	 0.5912806539509536
# aps:	 [0.607744799912527, 0.7740585482266875, 0.616990401790703, 0.6143759311632795]
# Fold 3
# acc:	 0.5613079019073569
# hamm:	 0.21934604904632152
# prec:	 0.5613079019073569
# sens:	 0.5613079019073569
# f1:	 0.5613079019073569
# aps:	 [0.5804853856916771, 0.6734133718951669, 0.5220852276523328, 0.4459697056879453]
# Fold 4
# acc:	 0.5694822888283378
# hamm:	 0.21525885558583105
# prec:	 0.5694822888283378
# sens:	 0.5694822888283378
# f1:	 0.5694822888283378
# aps:	 [0.5869585147755552, 0.6948851617969231, 0.5395284539382911, 0.5532565212064662]
# Fold 5
# acc:	 0.5667574931880109
# hamm:	 0.21662125340599456
# prec:	 0.5667574931880109
# sens:	 0.5667574931880109
# f1:	 0.5667574931880109
# aps:	 [0.562328614823865, 0.6760111044163399, 0.4892307026800577, 0.5312898272364749]
# ----- Combination 15 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.001) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.6032608695652174
# hamm:	 0.1983695652173913
# prec:	 0.6032608695652174
# sens:	 0.6032608695652174
# f1:	 0.6032608695652174
# aps:	 [0.5773139489370306, 0.7089622631785784, 0.6194878123071091, 0.5445890876801511]
# Fold 2
# acc:	 0.6403269754768393
# hamm:	 0.17983651226158037
# prec:	 0.6403269754768393
# sens:	 0.6403269754768393
# f1:	 0.6403269754768393
# aps:	 [0.7107775651087633, 0.7585778911738545, 0.6029056344338171, 0.6104601375699737]
# Fold 3
# acc:	 0.547683923705722
# hamm:	 0.22615803814713897
# prec:	 0.547683923705722
# sens:	 0.547683923705722
# f1:	 0.547683923705722
# aps:	 [0.5991298115150616, 0.7076914752176312, 0.527036612211003, 0.4525807714763852]
# Fold 4
# acc:	 0.6076294277929155
# hamm:	 0.19618528610354224
# prec:	 0.6076294277929155
# sens:	 0.6076294277929155
# f1:	 0.6076294277929155
# aps:	 [0.6098932271058632, 0.6745050676227308, 0.5754062793647378, 0.5724839940127217]
# Fold 5
# acc:	 0.5667574931880109
# hamm:	 0.21662125340599456
# prec:	 0.5667574931880109
# sens:	 0.5667574931880109
# f1:	 0.5667574931880109
# aps:	 [0.5943826675897447, 0.6860259643670655, 0.42265241830074696, 0.5621306988408397]
# ----- Combination 16 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.001) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.592391304347826
# hamm:	 0.20380434782608695
# prec:	 0.592391304347826
# sens:	 0.592391304347826
# f1:	 0.592391304347826
# aps:	 [0.5858160542766393, 0.6940843898317726, 0.6196491174421251, 0.537024587819914]
# Fold 2
# acc:	 0.6239782016348774
# hamm:	 0.1880108991825613
# prec:	 0.6239782016348774
# sens:	 0.6239782016348774
# f1:	 0.6239782016348774
# aps:	 [0.6953842507264741, 0.7704001919383016, 0.6198475252818625, 0.6211083524038057]
# Fold 3
# acc:	 0.5395095367847411
# hamm:	 0.23024523160762944
# prec:	 0.5395095367847411
# sens:	 0.5395095367847411
# f1:	 0.5395095367847411
# aps:	 [0.5935398688682213, 0.7089735247869272, 0.5347088000918834, 0.45625943810227254]
# Fold 4
# acc:	 0.6049046321525886
# hamm:	 0.19754768392370572
# prec:	 0.6049046321525886
# sens:	 0.6049046321525886
# f1:	 0.6049046321525886
# aps:	 [0.6190349442677168, 0.6787073432849082, 0.5417019704888761, 0.5572130912011268]
# Fold 5
# acc:	 0.5858310626702997
# hamm:	 0.20708446866485014
# prec:	 0.5858310626702997
# sens:	 0.5858310626702997
# f1:	 0.5858310626702997
# aps:	 [0.5864782142673367, 0.6871406634767048, 0.421142055637778, 0.5538539017690486]
# ----- Combination 17 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.001) ('batch_size', 64) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5788043478260869
# hamm:	 0.2105978260869565
# prec:	 0.5788043478260869
# sens:	 0.5788043478260869
# f1:	 0.5788043478260869
# aps:	 [0.5736807936387043, 0.6916931824806468, 0.6122263181863435, 0.5262743620551074]
# Fold 2
# acc:	 0.6321525885558583
# hamm:	 0.18392370572207084
# prec:	 0.6321525885558583
# sens:	 0.6321525885558583
# f1:	 0.6321525885558583
# aps:	 [0.6848887812034584, 0.7723555083349781, 0.6113742458731474, 0.6359157205459237]
# Fold 3
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.5855288486997032, 0.7125132181258683, 0.5348063867089231, 0.45714461930063155]
# Fold 4
# acc:	 0.6021798365122616
# hamm:	 0.1989100817438692
# prec:	 0.6021798365122616
# sens:	 0.6021798365122616
# f1:	 0.6021798365122616
# aps:	 [0.6145494719877601, 0.6785947625335724, 0.5479350755139126, 0.5698821393609544]
# Fold 5
# acc:	 0.6021798365122616
# hamm:	 0.1989100817438692
# prec:	 0.6021798365122616
# sens:	 0.6021798365122616
# f1:	 0.6021798365122616
# aps:	 [0.5827745772051759, 0.6938065588007682, 0.4267433357362101, 0.5527904284506292]
# ----- Combination 18 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.001) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5869565217391305
# hamm:	 0.20652173913043478
# prec:	 0.5869565217391305
# sens:	 0.5869565217391305
# f1:	 0.5869565217391305
# aps:	 [0.569264731401576, 0.6919289022272368, 0.6174079257339121, 0.5255411420476854]
# Fold 2
# acc:	 0.6348773841961853
# hamm:	 0.18256130790190736
# prec:	 0.6348773841961853
# sens:	 0.6348773841961853
# f1:	 0.6348773841961853
# aps:	 [0.6663714416728226, 0.7789909872521686, 0.6231204526958246, 0.6300741189542775]
# Fold 3
# acc:	 0.5395095367847411
# hamm:	 0.23024523160762944
# prec:	 0.5395095367847411
# sens:	 0.5395095367847411
# f1:	 0.5395095367847411
# aps:	 [0.5860257882020536, 0.7014707819611318, 0.5219558321343152, 0.442390922909179]
# Fold 4
# acc:	 0.6076294277929155
# hamm:	 0.19618528610354224
# prec:	 0.6076294277929155
# sens:	 0.6076294277929155
# f1:	 0.6076294277929155
# aps:	 [0.6113992192777944, 0.683545372243995, 0.5468786748099859, 0.5681810455626348]
# Fold 5
# acc:	 0.5803814713896458
# hamm:	 0.2098092643051771
# prec:	 0.5803814713896458
# sens:	 0.5803814713896458
# f1:	 0.5803814713896458
# aps:	 [0.5829389627223395, 0.6893866685740577, 0.43735132816398103, 0.5511697329006808]
# ----- Combination 19 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.001) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5815217391304348
# hamm:	 0.20923913043478262
# prec:	 0.5815217391304348
# sens:	 0.5815217391304348
# f1:	 0.5815217391304348
# aps:	 [0.5831824130538813, 0.6912127169666569, 0.6246564889190355, 0.5369286210329709]
# Fold 2
# acc:	 0.6158038147138964
# hamm:	 0.19209809264305178
# prec:	 0.6158038147138964
# sens:	 0.6158038147138964
# f1:	 0.6158038147138964
# aps:	 [0.6517846929030531, 0.7775573304472078, 0.6181144653763909, 0.6314865136177863]
# Fold 3
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.5872753610208346, 0.7073396596057449, 0.5261567276912071, 0.4500787703924421]
# Fold 4
# acc:	 0.5912806539509536
# hamm:	 0.20435967302452315
# prec:	 0.5912806539509536
# sens:	 0.5912806539509536
# f1:	 0.5912806539509536
# aps:	 [0.6083716059478238, 0.6801361572406758, 0.5478168988420995, 0.5572309153315625]
# Fold 5
# acc:	 0.5912806539509536
# hamm:	 0.20435967302452315
# prec:	 0.5912806539509536
# sens:	 0.5912806539509536
# f1:	 0.5912806539509536
# aps:	 [0.5929004122827052, 0.6914007299515293, 0.4458996072461446, 0.5423816363869853]
# ----- Combination 20 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.005) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5788043478260869
# hamm:	 0.2105978260869565
# prec:	 0.5788043478260869
# sens:	 0.5788043478260869
# f1:	 0.5788043478260869
# aps:	 [0.5698695630198247, 0.6904041725689398, 0.6227948526099871, 0.5401954545991718]
# Fold 2
# acc:	 0.6348773841961853
# hamm:	 0.18256130790190736
# prec:	 0.6348773841961853
# sens:	 0.6348773841961853
# f1:	 0.6348773841961853
# aps:	 [0.6860681238410142, 0.7721720147989515, 0.6018546430938276, 0.6133944945025174]
# Fold 3
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.6026878234712686, 0.7034376691292901, 0.5212705520645123, 0.45309813393358633]
# Fold 4
# acc:	 0.6158038147138964
# hamm:	 0.19209809264305178
# prec:	 0.6158038147138964
# sens:	 0.6158038147138964
# f1:	 0.6158038147138964
# aps:	 [0.6174692873461771, 0.680748482036662, 0.5675773575200358, 0.5648280683544937]
# Fold 5
# acc:	 0.5694822888283378
# hamm:	 0.21525885558583105
# prec:	 0.5694822888283378
# sens:	 0.5694822888283378
# f1:	 0.5694822888283378
# aps:	 [0.6143781497253494, 0.6919051996215331, 0.40267030761323136, 0.5569342515265734]
# ----- Combination 21 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.005) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.595108695652174
# hamm:	 0.20244565217391305
# prec:	 0.595108695652174
# sens:	 0.595108695652174
# f1:	 0.595108695652174
# aps:	 [0.5803941159760859, 0.6828075597696421, 0.6077149748527975, 0.5398323766300305]
# Fold 2
# acc:	 0.6348773841961853
# hamm:	 0.18256130790190736
# prec:	 0.6348773841961853
# sens:	 0.6348773841961853
# f1:	 0.6348773841961853
# aps:	 [0.692932637101779, 0.7813651544147321, 0.6215569400389694, 0.6278500241679333]
# Fold 3
# acc:	 0.5504087193460491
# hamm:	 0.22479564032697547
# prec:	 0.5504087193460491
# sens:	 0.5504087193460491
# f1:	 0.5504087193460491
# aps:	 [0.5756540288853975, 0.712442842101315, 0.5316590378316594, 0.4541555223829175]
# Fold 4
# acc:	 0.6212534059945504
# hamm:	 0.1893732970027248
# prec:	 0.6212534059945504
# sens:	 0.6212534059945504
# f1:	 0.6212534059945504
# aps:	 [0.6094945146545351, 0.6747607926807703, 0.5588558965338073, 0.5656309281174313]
# Fold 5
# acc:	 0.5803814713896458
# hamm:	 0.2098092643051771
# prec:	 0.5803814713896458
# sens:	 0.5803814713896458
# f1:	 0.5803814713896458
# aps:	 [0.6021512166297386, 0.6789119239930134, 0.4345905777625063, 0.5506888857870531]
# ----- Combination 22 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.005) ('batch_size', 64) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5788043478260869
# hamm:	 0.2105978260869565
# prec:	 0.5788043478260869
# sens:	 0.5788043478260869
# f1:	 0.5788043478260869
# aps:	 [0.5646848557620892, 0.6884255398084221, 0.6177422931901699, 0.5259885648176752]
# Fold 2
# acc:	 0.6267029972752044
# hamm:	 0.18664850136239783
# prec:	 0.6267029972752044
# sens:	 0.6267029972752044
# f1:	 0.6267029972752044
# aps:	 [0.6784039559091513, 0.7809251430405251, 0.6135380969607631, 0.6350927339537488]
# Fold 3
# acc:	 0.547683923705722
# hamm:	 0.22615803814713897
# prec:	 0.547683923705722
# sens:	 0.547683923705722
# f1:	 0.547683923705722
# aps:	 [0.5892649632973311, 0.7122170672055688, 0.5309673349304551, 0.4511017084835286]
# Fold 4
# acc:	 0.6021798365122616
# hamm:	 0.1989100817438692
# prec:	 0.6021798365122616
# sens:	 0.6021798365122616
# f1:	 0.6021798365122616
# aps:	 [0.6022510783416749, 0.6871086983834649, 0.5446307088001504, 0.5670561180378308]
# Fold 5
# acc:	 0.5831062670299727
# hamm:	 0.20844686648501362
# prec:	 0.5831062670299727
# sens:	 0.5831062670299727
# f1:	 0.5831062670299727
# aps:	 [0.5875989834038872, 0.6971351548258734, 0.43003530670489776, 0.5557122839815714]
# ----- Combination 23 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.005) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5788043478260869
# hamm:	 0.2105978260869565
# prec:	 0.5788043478260869
# sens:	 0.5788043478260869
# f1:	 0.5788043478260869
# aps:	 [0.5717941642864595, 0.6915696978385024, 0.6177402159005139, 0.5263832385252605]
# Fold 2
# acc:	 0.6239782016348774
# hamm:	 0.1880108991825613
# prec:	 0.6239782016348774
# sens:	 0.6239782016348774
# f1:	 0.6239782016348774
# aps:	 [0.660576952444598, 0.7878066379533659, 0.6124030384544056, 0.6360458424831755]
# Fold 3
# acc:	 0.5395095367847411
# hamm:	 0.23024523160762944
# prec:	 0.5395095367847411
# sens:	 0.5395095367847411
# f1:	 0.5395095367847411
# aps:	 [0.5916781905204999, 0.7009909764753947, 0.527895880441261, 0.4489020457799766]
# Fold 4
# acc:	 0.6021798365122616
# hamm:	 0.1989100817438692
# prec:	 0.6021798365122616
# sens:	 0.6021798365122616
# f1:	 0.6021798365122616
# aps:	 [0.6009448612616778, 0.684220832920927, 0.5491820627262847, 0.5654950764966474]
# Fold 5
# acc:	 0.5803814713896458
# hamm:	 0.2098092643051771
# prec:	 0.5803814713896458
# sens:	 0.5803814713896458
# f1:	 0.5803814713896458
# aps:	 [0.5852425259458787, 0.6897214780994231, 0.44917679746116296, 0.5437472767400127]
# ----- Combination 24 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.005) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.592391304347826
# hamm:	 0.20380434782608695
# prec:	 0.592391304347826
# sens:	 0.592391304347826
# f1:	 0.592391304347826
# aps:	 [0.5844849856611, 0.6889942718270069, 0.6209931124828835, 0.5336081051726664]
# Fold 2
# acc:	 0.6076294277929155
# hamm:	 0.19618528610354224
# prec:	 0.6076294277929155
# sens:	 0.6076294277929155
# f1:	 0.6076294277929155
# aps:	 [0.6502722958083046, 0.7808284180874884, 0.608473096133725, 0.6301682402803102]
# Fold 3
# acc:	 0.5422343324250681
# hamm:	 0.22888283378746593
# prec:	 0.5422343324250681
# sens:	 0.5422343324250681
# f1:	 0.5422343324250681
# aps:	 [0.5877683097114323, 0.7140202499425734, 0.531261483956351, 0.4456412979380592]
# Fold 4
# acc:	 0.5940054495912807
# hamm:	 0.20299727520435967
# prec:	 0.5940054495912807
# sens:	 0.5940054495912807
# f1:	 0.5940054495912807
# aps:	 [0.6165747444944395, 0.6837890963690895, 0.5483219715115026, 0.5541064848839921]
# Fold 5
# acc:	 0.5885558583106267
# hamm:	 0.20572207084468666
# prec:	 0.5885558583106267
# sens:	 0.5885558583106267
# f1:	 0.5885558583106267
# aps:	 [0.5954596467931508, 0.6957899768412427, 0.4462775080940773, 0.5473234418130624]
# ----- Combination 25 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.01) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5842391304347826
# hamm:	 0.2078804347826087
# prec:	 0.5842391304347826
# sens:	 0.5842391304347826
# f1:	 0.5842391304347826
# aps:	 [0.5731284156384716, 0.6959046657855109, 0.6127413888466449, 0.5394348098029865]
# Fold 2
# acc:	 0.6376021798365122
# hamm:	 0.18119891008174388
# prec:	 0.6376021798365122
# sens:	 0.6376021798365122
# f1:	 0.6376021798365122
# aps:	 [0.7057542840628617, 0.7641103607467696, 0.5934464104249724, 0.6132471740304363]
# Fold 3
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.5895524271045524, 0.7027675230654512, 0.5241673518294105, 0.45382736024437537]
# Fold 4
# acc:	 0.6103542234332425
# hamm:	 0.19482288828337874
# prec:	 0.6103542234332425
# sens:	 0.6103542234332425
# f1:	 0.6103542234332425
# aps:	 [0.6005872812637915, 0.680339916671788, 0.5725404337531639, 0.5716072299393996]
# Fold 5
# acc:	 0.5694822888283378
# hamm:	 0.21525885558583105
# prec:	 0.5694822888283378
# sens:	 0.5694822888283378
# f1:	 0.5694822888283378
# aps:	 [0.6136216452544424, 0.6833791856705073, 0.41884392683111815, 0.5543326747813604]
# ----- Combination 26 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.01) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5842391304347826
# hamm:	 0.2078804347826087
# prec:	 0.5842391304347826
# sens:	 0.5842391304347826
# f1:	 0.5842391304347826
# aps:	 [0.5774004222223987, 0.6861011360532863, 0.6205923439649972, 0.5347159563902552]
# Fold 2
# acc:	 0.6403269754768393
# hamm:	 0.17983651226158037
# prec:	 0.6403269754768393
# sens:	 0.6403269754768393
# f1:	 0.6403269754768393
# aps:	 [0.6895131141494972, 0.7824450000492932, 0.6151507510290302, 0.6300536719826016]
# Fold 3
# acc:	 0.5395095367847411
# hamm:	 0.23024523160762944
# prec:	 0.5395095367847411
# sens:	 0.5395095367847411
# f1:	 0.5395095367847411
# aps:	 [0.5979734968838208, 0.7102860333330605, 0.5359730113191, 0.44974305563470385]
# Fold 4
# acc:	 0.6076294277929155
# hamm:	 0.19618528610354224
# prec:	 0.6076294277929155
# sens:	 0.6076294277929155
# f1:	 0.6076294277929155
# aps:	 [0.6074012413320551, 0.6845755675467267, 0.5504935675721611, 0.5567990212571252]
# Fold 5
# acc:	 0.5885558583106267
# hamm:	 0.20572207084468666
# prec:	 0.5885558583106267
# sens:	 0.5885558583106267
# f1:	 0.5885558583106267
# aps:	 [0.6037476956767208, 0.6852757903667035, 0.4401582210500817, 0.5544709069454151]
# ----- Combination 27 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.01) ('batch_size', 64) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5760869565217391
# hamm:	 0.21195652173913043
# prec:	 0.5760869565217391
# sens:	 0.5760869565217391
# f1:	 0.5760869565217391
# aps:	 [0.5588481835900279, 0.6847209111377166, 0.6124684839220077, 0.5263138787210396]
# Fold 2
# acc:	 0.6403269754768393
# hamm:	 0.17983651226158037
# prec:	 0.6403269754768393
# sens:	 0.6403269754768393
# f1:	 0.6403269754768393
# aps:	 [0.6867369580950826, 0.7835094198345218, 0.6260745280342422, 0.6298825381226754]
# Fold 3
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.5784547243541599, 0.7099480354934465, 0.5312046854755555, 0.45350308728129196]
# Fold 4
# acc:	 0.6130790190735694
# hamm:	 0.19346049046321526
# prec:	 0.6130790190735694
# sens:	 0.6130790190735694
# f1:	 0.6130790190735694
# aps:	 [0.6088824820369053, 0.6833253190388152, 0.5524869116309349, 0.5692909715509391]
# Fold 5
# acc:	 0.5858310626702997
# hamm:	 0.20708446866485014
# prec:	 0.5858310626702997
# sens:	 0.5858310626702997
# f1:	 0.5858310626702997
# aps:	 [0.594548344858363, 0.701331265383227, 0.422315311740853, 0.5582752786219076]
# ----- Combination 28 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.01) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5842391304347826
# hamm:	 0.2078804347826087
# prec:	 0.5842391304347826
# sens:	 0.5842391304347826
# f1:	 0.5842391304347826
# aps:	 [0.5617530968291273, 0.6819971787863549, 0.6160448997180666, 0.5221068056559011]
# Fold 2
# acc:	 0.6185286103542235
# hamm:	 0.1907356948228883
# prec:	 0.6185286103542235
# sens:	 0.6185286103542235
# f1:	 0.6185286103542235
# aps:	 [0.6570055794772289, 0.782551036592408, 0.6159639587817071, 0.6204679339040059]
# Fold 3
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.587197964875378, 0.6976711798591063, 0.5280905381157178, 0.45057724766358975]
# Fold 4
# acc:	 0.6021798365122616
# hamm:	 0.1989100817438692
# prec:	 0.6021798365122616
# sens:	 0.6021798365122616
# f1:	 0.6021798365122616
# aps:	 [0.6134785580113479, 0.6900784590621245, 0.5570950392655958, 0.5666838829896229]
# Fold 5
# acc:	 0.5858310626702997
# hamm:	 0.20708446866485014
# prec:	 0.5858310626702997
# sens:	 0.5858310626702997
# f1:	 0.5858310626702997
# aps:	 [0.5878742154602951, 0.6870502930686366, 0.45498407830121734, 0.5421910411630819]
# ----- Combination 29 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.002) ('weight_decay', 0.01) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5788043478260869
# hamm:	 0.2105978260869565
# prec:	 0.5788043478260869
# sens:	 0.5788043478260869
# f1:	 0.5788043478260869
# aps:	 [0.5884252636028592, 0.6865004719502076, 0.6198634463988855, 0.5254302718879238]
# Fold 2
# acc:	 0.6049046321525886
# hamm:	 0.19754768392370572
# prec:	 0.6049046321525886
# sens:	 0.6049046321525886
# f1:	 0.6049046321525886
# aps:	 [0.6522461582649244, 0.7729173841025121, 0.6139706940143724, 0.6327821189561379]
# Fold 3
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.5858031930410559, 0.7115756867103873, 0.5304657220463954, 0.4511482786970724]
# Fold 4
# acc:	 0.5940054495912807
# hamm:	 0.20299727520435967
# prec:	 0.5940054495912807
# sens:	 0.5940054495912807
# f1:	 0.5940054495912807
# aps:	 [0.6165139629590346, 0.6850435736107352, 0.5441678632651604, 0.5577624896738903]
# Fold 5
# acc:	 0.5858310626702997
# hamm:	 0.20708446866485014
# prec:	 0.5858310626702997
# sens:	 0.5858310626702997
# f1:	 0.5858310626702997
# aps:	 [0.5912471192882516, 0.6908963627525216, 0.45756957802847803, 0.5436673691134231]
# ----- Combination 30 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.003) ('weight_decay', 0.001) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5978260869565217
# hamm:	 0.20108695652173914
# prec:	 0.5978260869565217
# sens:	 0.5978260869565217
# f1:	 0.5978260869565217
# aps:	 [0.5590532171712141, 0.6998967808554885, 0.6222008064322578, 0.5321527542745768]
# Fold 2
# acc:	 0.6158038147138964
# hamm:	 0.19209809264305178
# prec:	 0.6158038147138964
# sens:	 0.6158038147138964
# f1:	 0.6158038147138964
# aps:	 [0.745305453828421, 0.7587752686500644, 0.5769354571677023, 0.5803058836227825]
# Fold 3
# acc:	 0.5258855585831063
# hamm:	 0.23705722070844687
# prec:	 0.5258855585831063
# sens:	 0.5258855585831063
# f1:	 0.5258855585831063
# aps:	 [0.5792099404321904, 0.6890447110880662, 0.500089165591074, 0.4485635174064557]
# Fold 4
# acc:	 0.5803814713896458
# hamm:	 0.2098092643051771
# prec:	 0.5803814713896458
# sens:	 0.5803814713896458
# f1:	 0.5803814713896458
# aps:	 [0.6122741176594099, 0.6763827132048648, 0.571600326938636, 0.5557516229222096]
# Fold 5
# acc:	 0.5749318801089919
# hamm:	 0.2125340599455041
# prec:	 0.5749318801089919
# sens:	 0.5749318801089919
# f1:	 0.5749318801089919
# aps:	 [0.5923591239051164, 0.6891641668975476, 0.38270011356991995, 0.5668745900778436]
# ----- Combination 31 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.003) ('weight_decay', 0.001) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5869565217391305
# hamm:	 0.20652173913043478
# prec:	 0.5869565217391305
# sens:	 0.5869565217391305
# f1:	 0.5869565217391305
# aps:	 [0.5812054085509175, 0.6890515852199322, 0.6140502204954998, 0.5550384759536499]
# Fold 2
# acc:	 0.6239782016348774
# hamm:	 0.1880108991825613
# prec:	 0.6239782016348774
# sens:	 0.6239782016348774
# f1:	 0.6239782016348774
# aps:	 [0.7338711646835683, 0.7599839432182133, 0.58367613590476, 0.6047753531625728]
# Fold 3
# acc:	 0.5504087193460491
# hamm:	 0.22479564032697547
# prec:	 0.5504087193460491
# sens:	 0.5504087193460491
# f1:	 0.5504087193460491
# aps:	 [0.5850631602766887, 0.6918755311970646, 0.5230782046169943, 0.4599079546586063]
# Fold 4
# acc:	 0.6021798365122616
# hamm:	 0.1989100817438692
# prec:	 0.6021798365122616
# sens:	 0.6021798365122616
# f1:	 0.6021798365122616
# aps:	 [0.6142977318798943, 0.6893198219728668, 0.5920488941873132, 0.5750712363043643]
# Fold 5
# acc:	 0.5803814713896458
# hamm:	 0.2098092643051771
# prec:	 0.5803814713896458
# sens:	 0.5803814713896458
# f1:	 0.5803814713896458
# aps:	 [0.5970568020852602, 0.6856974322583155, 0.400006609844375, 0.5683159741512533]
# ----- Combination 32 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.003) ('weight_decay', 0.001) ('batch_size', 64) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5842391304347826
# hamm:	 0.2078804347826087
# prec:	 0.5842391304347826
# sens:	 0.5842391304347826
# f1:	 0.5842391304347826
# aps:	 [0.5715086310022363, 0.6865557480778296, 0.6211305242827713, 0.5335749279791193]
# Fold 2
# acc:	 0.6239782016348774
# hamm:	 0.1880108991825613
# prec:	 0.6239782016348774
# sens:	 0.6239782016348774
# f1:	 0.6239782016348774
# aps:	 [0.7053813773264221, 0.7699866512808952, 0.6060940179673281, 0.6119695793146197]
# Fold 3
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.5905948210039716, 0.7072008926945509, 0.5163629890552147, 0.44920691974479227]
# Fold 4
# acc:	 0.6076294277929155
# hamm:	 0.19618528610354224
# prec:	 0.6076294277929155
# sens:	 0.6076294277929155
# f1:	 0.6076294277929155
# aps:	 [0.605333210175754, 0.6726218885878362, 0.5440907280271023, 0.5709717952488774]
# Fold 5
# acc:	 0.5694822888283378
# hamm:	 0.21525885558583105
# prec:	 0.5694822888283378
# sens:	 0.5694822888283378
# f1:	 0.5694822888283378
# aps:	 [0.6056947745942015, 0.6751737872876742, 0.39174410733035686, 0.5630027803412958]
# ----- Combination 33 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.003) ('weight_decay', 0.001) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5869565217391305
# hamm:	 0.20652173913043478
# prec:	 0.5869565217391305
# sens:	 0.5869565217391305
# f1:	 0.5869565217391305
# aps:	 [0.5712419275071569, 0.6955954148604181, 0.6163012927535034, 0.5305064504530357]
# Fold 2
# acc:	 0.6457765667574932
# hamm:	 0.1771117166212534
# prec:	 0.6457765667574932
# sens:	 0.6457765667574932
# f1:	 0.6457765667574932
# aps:	 [0.6940775353250301, 0.7816730758737357, 0.6081563434832161, 0.6243364929984729]
# Fold 3
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.5874056188375525, 0.7186431822880504, 0.5055016553727055, 0.4463958932802574]
# Fold 4
# acc:	 0.5967302452316077
# hamm:	 0.2016348773841962
# prec:	 0.5967302452316077
# sens:	 0.5967302452316077
# f1:	 0.5967302452316077
# aps:	 [0.6066212302119615, 0.6734466283003825, 0.5512014752880692, 0.56811885857037]
# Fold 5
# acc:	 0.5885558583106267
# hamm:	 0.20572207084468666
# prec:	 0.5885558583106267
# sens:	 0.5885558583106267
# f1:	 0.5885558583106267
# aps:	 [0.5907759363953519, 0.6933145715304371, 0.4116288543164602, 0.5602699998003715]
# ----- Combination 34 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.003) ('weight_decay', 0.001) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5869565217391305
# hamm:	 0.20652173913043478
# prec:	 0.5869565217391305
# sens:	 0.5869565217391305
# f1:	 0.5869565217391305
# aps:	 [0.5736252279459929, 0.6932278770601841, 0.6223880880695879, 0.5364739970844072]
# Fold 2
# acc:	 0.6457765667574932
# hamm:	 0.1771117166212534
# prec:	 0.6457765667574932
# sens:	 0.6457765667574932
# f1:	 0.6457765667574932
# aps:	 [0.6926193924424168, 0.7838089241292118, 0.6022956883705604, 0.6175268685402184]
# Fold 3
# acc:	 0.547683923705722
# hamm:	 0.22615803814713897
# prec:	 0.547683923705722
# sens:	 0.547683923705722
# f1:	 0.547683923705722
# aps:	 [0.588314821982279, 0.7152606420627932, 0.5186516922668368, 0.44693371510865904]
# Fold 4
# acc:	 0.6021798365122616
# hamm:	 0.1989100817438692
# prec:	 0.6021798365122616
# sens:	 0.6021798365122616
# f1:	 0.6021798365122616
# aps:	 [0.5957726017848469, 0.683666272834219, 0.5412627781232128, 0.5647067220688833]
# Fold 5
# acc:	 0.5885558583106267
# hamm:	 0.20572207084468666
# prec:	 0.5885558583106267
# sens:	 0.5885558583106267
# f1:	 0.5885558583106267
# aps:	 [0.5950390044222721, 0.6856729998258149, 0.4102184537692027, 0.5552670371197576]
# ----- Combination 35 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.003) ('weight_decay', 0.005) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5896739130434783
# hamm:	 0.20516304347826086
# prec:	 0.5896739130434783
# sens:	 0.5896739130434783
# f1:	 0.5896739130434783
# aps:	 [0.5639239005600746, 0.7210266476247534, 0.6151013282303313, 0.5397181896108003]
# Fold 2
# acc:	 0.6267029972752044
# hamm:	 0.18664850136239783
# prec:	 0.6267029972752044
# sens:	 0.6267029972752044
# f1:	 0.6267029972752044
# aps:	 [0.7412898204582261, 0.7731403236623892, 0.5589600035973795, 0.5885400872285678]
# Fold 3
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.5845825347580936, 0.7066639943377104, 0.5096860431998683, 0.45559878574584795]
# Fold 4
# acc:	 0.5858310626702997
# hamm:	 0.20708446866485014
# prec:	 0.5858310626702997
# sens:	 0.5858310626702997
# f1:	 0.5858310626702997
# aps:	 [0.6163353840948489, 0.6678239905767082, 0.5795904223973094, 0.5513529100669211]
# Fold 5
# acc:	 0.5803814713896458
# hamm:	 0.2098092643051771
# prec:	 0.5803814713896458
# sens:	 0.5803814713896458
# f1:	 0.5803814713896458
# aps:	 [0.5896958063181605, 0.6704981193813161, 0.3829055469917405, 0.560399393810659]
# ----- Combination 36 -----
# ('num_hidden_layers', 0) ('layer_size', 64) ('lr', 0.003) ('weight_decay', 0.005) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5978260869565217
# hamm:	 0.20108695652173914
# prec:	 0.5978260869565217
# sens:	 0.5978260869565217
# f1:	 0.5978260869565217
# aps:	 [0.5736493326391731, 0.692087011306444, 0.6185074363634552, 0.5428628128691724]
# Fold 2
# acc:	 0.6376021798365122
# hamm:	 0.18119891008174388
# ...
# f1:	 0.547683923705722
# aps:	 [0.5962821129079426, 0.6478775708171696, 0.29426712757730783, 0.5251991944911243]
# ----- Combination 258 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.001) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5896739130434783
# hamm:	 0.20516304347826086
# prec:	 0.5896739130434783
# sens:	 0.5896739130434783
# f1:	 0.5896739130434783
# aps:	 [0.5595522755619452, 0.7248853122598427, 0.6489969652228449, 0.5256838483427106]
# Fold 2
# acc:	 0.5994550408719346
# hamm:	 0.20027247956403268
# prec:	 0.5994550408719346
# sens:	 0.5994550408719346
# f1:	 0.5994550408719346
# aps:	 [0.7178210787725529, 0.744869480612366, 0.5578923696673914, 0.5374904564272265]
# Fold 3
# acc:	 0.5395095367847411
# hamm:	 0.23024523160762944
# prec:	 0.5395095367847411
# sens:	 0.5395095367847411
# f1:	 0.5395095367847411
# aps:	 [0.5967719754994867, 0.6784424474844162, 0.5596131277859949, 0.43493365570527887]
# Fold 4
# acc:	 0.5722070844686649
# hamm:	 0.21389645776566757
# prec:	 0.5722070844686649
# sens:	 0.5722070844686649
# f1:	 0.5722070844686649
# aps:	 [0.6277549796306137, 0.6712712227195252, 0.5307119454971881, 0.579549681850581]
# Fold 5
# acc:	 0.5422343324250681
# hamm:	 0.22888283378746593
# prec:	 0.5422343324250681
# sens:	 0.5422343324250681
# f1:	 0.5422343324250681
# aps:	 [0.5969037028085756, 0.6609934732622058, 0.3062210031810528, 0.5480155820588788]
# ----- Combination 259 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.001) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.595108695652174
# hamm:	 0.20244565217391305
# prec:	 0.595108695652174
# sens:	 0.595108695652174
# f1:	 0.595108695652174
# aps:	 [0.5924384191634767, 0.7200471518809892, 0.6252845217880607, 0.5660298843185578]
# Fold 2
# acc:	 0.6158038147138964
# hamm:	 0.19209809264305178
# prec:	 0.6158038147138964
# sens:	 0.6158038147138964
# f1:	 0.6158038147138964
# aps:	 [0.7152043897909072, 0.7500281961689945, 0.554599413540962, 0.5663608601338878]
# Fold 3
# acc:	 0.5367847411444142
# hamm:	 0.23160762942779292
# prec:	 0.5367847411444142
# sens:	 0.5367847411444142
# f1:	 0.5367847411444142
# aps:	 [0.5891426043359032, 0.6798386452504347, 0.5634103651491238, 0.42694491588119093]
# Fold 4
# acc:	 0.5722070844686649
# hamm:	 0.21389645776566757
# prec:	 0.5722070844686649
# sens:	 0.5722070844686649
# f1:	 0.5722070844686649
# aps:	 [0.6176875496436491, 0.6680739699082829, 0.5522488858509651, 0.5787665734223679]
# Fold 5
# acc:	 0.5667574931880109
# hamm:	 0.21662125340599456
# prec:	 0.5667574931880109
# sens:	 0.5667574931880109
# f1:	 0.5667574931880109
# aps:	 [0.5831564278477511, 0.6514132010512986, 0.3719232289847699, 0.5508142728312744]
# ----- Combination 260 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.005) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5978260869565217
# hamm:	 0.20108695652173914
# prec:	 0.5978260869565217
# sens:	 0.5978260869565217
# f1:	 0.5978260869565217
# aps:	 [0.5787608576441028, 0.7136570388081246, 0.651725100930243, 0.5766199965875636]
# Fold 2
# acc:	 0.6239782016348774
# hamm:	 0.1880108991825613
# prec:	 0.6239782016348774
# sens:	 0.6239782016348774
# f1:	 0.6239782016348774
# aps:	 [0.757116438400082, 0.7354679789144214, 0.528329691802806, 0.5370506288981065]
# Fold 3
# acc:	 0.5422343324250681
# hamm:	 0.22888283378746593
# prec:	 0.5422343324250681
# sens:	 0.5422343324250681
# f1:	 0.5422343324250681
# aps:	 [0.5639899997623447, 0.6903210705343403, 0.5552606172863095, 0.4054139457792613]
# Fold 4
# acc:	 0.55858310626703
# hamm:	 0.22070844686648503
# prec:	 0.55858310626703
# sens:	 0.55858310626703
# f1:	 0.55858310626703
# aps:	 [0.6072969803850804, 0.6748116054138091, 0.5232599265894452, 0.5849279994329194]
# Fold 5
# acc:	 0.5340599455040872
# hamm:	 0.2329700272479564
# prec:	 0.5340599455040872
# sens:	 0.5340599455040872
# f1:	 0.5340599455040872
# aps:	 [0.5667320375319096, 0.6539236633253529, 0.3302479287576292, 0.5476750682633266]
# ----- Combination 261 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.005) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5706521739130435
# hamm:	 0.21467391304347827
# prec:	 0.5706521739130435
# sens:	 0.5706521739130435
# f1:	 0.5706521739130435
# aps:	 [0.5768869458406569, 0.7108727835129097, 0.6279230904573319, 0.5528329422645636]
# Fold 2
# acc:	 0.5967302452316077
# hamm:	 0.2016348773841962
# prec:	 0.5967302452316077
# sens:	 0.5967302452316077
# f1:	 0.5967302452316077
# aps:	 [0.7174771334782103, 0.7298048575636381, 0.5469528503712802, 0.5390941134949865]
# Fold 3
# acc:	 0.5286103542234333
# hamm:	 0.2356948228882834
# prec:	 0.5286103542234333
# sens:	 0.5286103542234333
# f1:	 0.5286103542234333
# aps:	 [0.5988004287528395, 0.684903542082126, 0.5384007136453467, 0.4191671956522284]
# Fold 4
# acc:	 0.5640326975476839
# hamm:	 0.21798365122615804
# prec:	 0.5640326975476839
# sens:	 0.5640326975476839
# f1:	 0.5640326975476839
# aps:	 [0.5872349745226348, 0.6689211339144346, 0.5134566886140371, 0.5380597206041992]
# Fold 5
# acc:	 0.555858310626703
# hamm:	 0.2220708446866485
# prec:	 0.555858310626703
# sens:	 0.555858310626703
# f1:	 0.555858310626703
# aps:	 [0.5758649343760347, 0.6569253700900819, 0.3795165699772393, 0.5587763635168217]
# ----- Combination 262 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.005) ('batch_size', 64) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5815217391304348
# hamm:	 0.20923913043478262
# prec:	 0.5815217391304348
# sens:	 0.5815217391304348
# f1:	 0.5815217391304348
# aps:	 [0.5765131958233815, 0.7162495724554502, 0.6528551978675761, 0.5311326391432103]
# Fold 2
# acc:	 0.6076294277929155
# hamm:	 0.19618528610354224
# prec:	 0.6076294277929155
# sens:	 0.6076294277929155
# f1:	 0.6076294277929155
# aps:	 [0.7236414690284875, 0.750329841028855, 0.5198799392849227, 0.5576142043376195]
# Fold 3
# acc:	 0.5313351498637602
# hamm:	 0.23433242506811988
# prec:	 0.5313351498637602
# sens:	 0.5313351498637602
# f1:	 0.5313351498637602
# aps:	 [0.6082013238135758, 0.7005143530571121, 0.5571899765932891, 0.41371956965833034]
# Fold 4
# acc:	 0.5640326975476839
# hamm:	 0.21798365122615804
# prec:	 0.5640326975476839
# sens:	 0.5640326975476839
# f1:	 0.5640326975476839
# aps:	 [0.6074873580787542, 0.6609901616317628, 0.5561703582912655, 0.5585256692913185]
# Fold 5
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.5692914288217059, 0.6650779184787605, 0.29580511245301244, 0.547028481821776]
# ----- Combination 263 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.005) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.595108695652174
# hamm:	 0.20244565217391305
# prec:	 0.595108695652174
# sens:	 0.595108695652174
# f1:	 0.595108695652174
# aps:	 [0.5698421207660047, 0.7209286572205109, 0.6411434597858514, 0.5361353143839798]
# Fold 2
# acc:	 0.6185286103542235
# hamm:	 0.1907356948228883
# prec:	 0.6185286103542235
# sens:	 0.6185286103542235
# f1:	 0.6185286103542235
# aps:	 [0.7198958756718727, 0.7457406035689159, 0.5583629500947956, 0.5549315982002416]
# Fold 3
# acc:	 0.5258855585831063
# hamm:	 0.23705722070844687
# prec:	 0.5258855585831063
# sens:	 0.5258855585831063
# f1:	 0.5258855585831063
# aps:	 [0.5890355011891171, 0.690338628389306, 0.5486636759931933, 0.42604420067181004]
# Fold 4
# acc:	 0.5776566757493188
# hamm:	 0.2111716621253406
# prec:	 0.5776566757493188
# sens:	 0.5776566757493188
# f1:	 0.5776566757493188
# aps:	 [0.6077469069801366, 0.6909606970134671, 0.5220805727034609, 0.5931054733081115]
# Fold 5
# acc:	 0.553133514986376
# hamm:	 0.22343324250681199
# prec:	 0.553133514986376
# sens:	 0.553133514986376
# f1:	 0.553133514986376
# aps:	 [0.5682754308555341, 0.6530988405773481, 0.3326867509279979, 0.5335185923096688]
# ----- Combination 264 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.005) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5978260869565217
# hamm:	 0.20108695652173914
# prec:	 0.5978260869565217
# sens:	 0.5978260869565217
# f1:	 0.5978260869565217
# aps:	 [0.5984430839829683, 0.7235339545187005, 0.6597727542934332, 0.5624231156605916]
# Fold 2
# acc:	 0.6212534059945504
# hamm:	 0.1893732970027248
# prec:	 0.6212534059945504
# sens:	 0.6212534059945504
# f1:	 0.6212534059945504
# aps:	 [0.751917316784542, 0.750678423781001, 0.5631382689552901, 0.5897010847217954]
# Fold 3
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.6035881660242518, 0.6947402929238911, 0.534695718120007, 0.3988629216200692]
# Fold 4
# acc:	 0.5694822888283378
# hamm:	 0.21525885558583105
# prec:	 0.5694822888283378
# sens:	 0.5694822888283378
# f1:	 0.5694822888283378
# aps:	 [0.6142605085895179, 0.6708543460412371, 0.5137976198063583, 0.5654825680036389]
# Fold 5
# acc:	 0.5449591280653951
# hamm:	 0.22752043596730245
# prec:	 0.5449591280653951
# sens:	 0.5449591280653951
# f1:	 0.5449591280653951
# aps:	 [0.5877830851549608, 0.6581249410773503, 0.32185288603355566, 0.5538271822855467]
# ----- Combination 265 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.01) ('batch_size', 32) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.592391304347826
# hamm:	 0.20380434782608695
# prec:	 0.592391304347826
# sens:	 0.592391304347826
# f1:	 0.592391304347826
# aps:	 [0.5682825866130464, 0.713138829355559, 0.6280287679202268, 0.5543497938043693]
# Fold 2
# acc:	 0.5940054495912807
# hamm:	 0.20299727520435967
# prec:	 0.5940054495912807
# sens:	 0.5940054495912807
# f1:	 0.5940054495912807
# aps:	 [0.7160986496459446, 0.7339502073496565, 0.5587583348132436, 0.5344330271360241]
# Fold 3
# acc:	 0.5149863760217984
# hamm:	 0.24250681198910082
# prec:	 0.5149863760217984
# sens:	 0.5149863760217984
# f1:	 0.5149863760217984
# aps:	 [0.5761194289281487, 0.6637624209098437, 0.49910622499910007, 0.41869776302877393]
# Fold 4
# acc:	 0.5722070844686649
# hamm:	 0.21389645776566757
# prec:	 0.5722070844686649
# sens:	 0.5722070844686649
# f1:	 0.5722070844686649
# aps:	 [0.5887255882660136, 0.6569920678945451, 0.5172882895275233, 0.5231065898306688]
# Fold 5
# acc:	 0.5313351498637602
# hamm:	 0.23433242506811988
# prec:	 0.5313351498637602
# sens:	 0.5313351498637602
# f1:	 0.5313351498637602
# aps:	 [0.5884605507733514, 0.6653947530220333, 0.33159930564799145, 0.5455537191116844]
# ----- Combination 266 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.01) ('batch_size', 48) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.6005434782608695
# hamm:	 0.19972826086956522
# prec:	 0.6005434782608695
# sens:	 0.6005434782608695
# f1:	 0.6005434782608695
# aps:	 [0.5948752222084717, 0.727755879611926, 0.6474306307500154, 0.5704644268602209]
# Fold 2
# acc:	 0.6103542234332425
# hamm:	 0.19482288828337874
# prec:	 0.6103542234332425
# sens:	 0.6103542234332425
# f1:	 0.6103542234332425
# aps:	 [0.7288082177182682, 0.7532618741837691, 0.5689564665205465, 0.5881733126456414]
# Fold 3
# acc:	 0.547683923705722
# hamm:	 0.22615803814713897
# prec:	 0.547683923705722
# sens:	 0.547683923705722
# f1:	 0.547683923705722
# aps:	 [0.5929850132990261, 0.7065165353503937, 0.5489615513511807, 0.42566796338607743]
# Fold 4
# acc:	 0.5749318801089919
# hamm:	 0.2125340599455041
# prec:	 0.5749318801089919
# sens:	 0.5749318801089919
# f1:	 0.5749318801089919
# aps:	 [0.5954819428375524, 0.6698848156171272, 0.5155250148893165, 0.553245813459775]
# Fold 5
# acc:	 0.5204359673024523
# hamm:	 0.23978201634877383
# prec:	 0.5204359673024523
# sens:	 0.5204359673024523
# f1:	 0.5204359673024523
# aps:	 [0.5755433026482912, 0.6564963035183187, 0.35579082374511245, 0.5451465646717598]
# ----- Combination 267 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.01) ('batch_size', 64) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5978260869565217
# hamm:	 0.20108695652173914
# prec:	 0.5978260869565217
# sens:	 0.5978260869565217
# f1:	 0.5978260869565217
# aps:	 [0.5741149060613048, 0.6944769678419174, 0.6329814866085383, 0.5405980952340433]
# Fold 2
# acc:	 0.6185286103542235
# hamm:	 0.1907356948228883
# prec:	 0.6185286103542235
# sens:	 0.6185286103542235
# f1:	 0.6185286103542235
# aps:	 [0.73401236519591, 0.7636072187866447, 0.573349481386512, 0.5790697092591284]
# Fold 3
# acc:	 0.5340599455040872
# hamm:	 0.2329700272479564
# prec:	 0.5340599455040872
# sens:	 0.5340599455040872
# f1:	 0.5340599455040872
# aps:	 [0.5979194859119147, 0.6907368171328229, 0.5499588089352149, 0.41882086553187425]
# Fold 4
# acc:	 0.5640326975476839
# hamm:	 0.21798365122615804
# prec:	 0.5640326975476839
# sens:	 0.5640326975476839
# f1:	 0.5640326975476839
# aps:	 [0.6040675123564241, 0.6686970001046048, 0.5255209077025166, 0.5648925885189785]
# Fold 5
# acc:	 0.5613079019073569
# hamm:	 0.21934604904632152
# prec:	 0.5613079019073569
# sens:	 0.5613079019073569
# f1:	 0.5613079019073569
# aps:	 [0.5798233270055735, 0.6674858019232126, 0.32938292954888004, 0.5467068677474833]
# ----- Combination 268 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.01) ('batch_size', 80) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5978260869565217
# hamm:	 0.20108695652173914
# prec:	 0.5978260869565217
# sens:	 0.5978260869565217
# f1:	 0.5978260869565217
# aps:	 [0.5849049358340699, 0.7220417244377447, 0.6595216330661461, 0.554394560847953]
# Fold 2
# acc:	 0.6212534059945504
# hamm:	 0.1893732970027248
# prec:	 0.6212534059945504
# sens:	 0.6212534059945504
# f1:	 0.6212534059945504
# aps:	 [0.7247132616804062, 0.7700804913711352, 0.5788421460393267, 0.6035322929868199]
# Fold 3
# acc:	 0.5367847411444142
# hamm:	 0.23160762942779292
# prec:	 0.5367847411444142
# sens:	 0.5367847411444142
# f1:	 0.5367847411444142
# aps:	 [0.6190883912265509, 0.6911030168923711, 0.5439571207583652, 0.42884972179399444]
# Fold 4
# acc:	 0.5694822888283378
# hamm:	 0.21525885558583105
# prec:	 0.5694822888283378
# sens:	 0.5694822888283378
# f1:	 0.5694822888283378
# aps:	 [0.6262923140084723, 0.6759905912739217, 0.5383781526102448, 0.5790817714466651]
# Fold 5
# acc:	 0.5504087193460491
# hamm:	 0.22479564032697547
# prec:	 0.5504087193460491
# sens:	 0.5504087193460491
# f1:	 0.5504087193460491
# aps:	 [0.5945048666452601, 0.6745953164611471, 0.3162212550757464, 0.5448236326523609]
# ----- Combination 269 -----
# ('num_hidden_layers', 2) ('layer_size', 128) ('lr', 0.003) ('weight_decay', 0.01) ('batch_size', 96) ('BCE_weights_power', 0.5) ('BCE_weights_factor', 1.2) ('epochs', 20) ('curvature', -1)
# Fold 1
# acc:	 0.5978260869565217
# hamm:	 0.20108695652173914
# prec:	 0.5978260869565217
# sens:	 0.5978260869565217
# f1:	 0.5978260869565217
# aps:	 [0.5868221846482566, 0.7240974715372992, 0.6557898665512454, 0.5686664191478122]
# Fold 2
# acc:	 0.6321525885558583
# hamm:	 0.18392370572207084
# prec:	 0.6321525885558583
# sens:	 0.6321525885558583
# f1:	 0.6321525885558583
# aps:	 [0.732662245537517, 0.7851809888429275, 0.5551510960085557, 0.6022367097633752]
# Fold 3
# acc:	 0.5340599455040872
# hamm:	 0.2329700272479564
# prec:	 0.5340599455040872
# sens:	 0.5340599455040872
# f1:	 0.5340599455040872
# aps:	 [0.5971066606266457, 0.7034858187680259, 0.5147896114788256, 0.42288730374157246]
# Fold 4
# acc:	 0.5749318801089919
# hamm:	 0.2125340599455041
# prec:	 0.5749318801089919
# sens:	 0.5749318801089919
# f1:	 0.5749318801089919
# aps:	 [0.6247827461514861, 0.671816654738773, 0.5512621741640793, 0.5943120878253834]
# Fold 5
# acc:	 0.5422343324250681
# hamm:	 0.22888283378746593
# prec:	 0.5422343324250681
# sens:	 0.5422343324250681
# f1:	 0.5422343324250681
# aps:	 [0.5790946663910469, 0.6735347523227617, 0.35660238590279647, 0.5606925934286939]

# %%
import ast

# %%
grid_search_results = []
with open('data/grid_search_arc_mini.txt', 'r') as file:
    inlist = 0
    for line in file.readlines():
        if line[0:4] == '----':
            grid_search_results.append([])
            continue

        if line[0] == '(':
            continue

        if line[0:4] == 'Fold':
            grid_search_results[-1].append([])
            continue

        result = line.split('\t ')[1]

        if result[0] == '[':
            grid_search_results[-1][-1].append(np.array(ast.literal_eval(result)).mean())
            continue

        grid_search_results[-1][-1].append(float(result))


grid_search_results = np.array(grid_search_results)
grid_search_results.shape
# Out:
# (270, 5, 6)

# %%
grid_search_results.mean(axis=1)
# Out:
# array([[0.59313766, 0.20343117, 0.59313766, 0.59313766, 0.59313766,
#         0.60317213],
#        [0.57461646, 0.21269177, 0.57461646, 0.57461646, 0.57461646,
#         0.59815192],
#        [0.57625726, 0.21187137, 0.57625726, 0.57625726, 0.57625726,
#         0.59500049],
#        ...,
#        [0.57515105, 0.21242448, 0.57515105, 0.57515105, 0.57515105,
#         0.59181116],
#        [0.57515105, 0.21242448, 0.57515105, 0.57515105, 0.57515105,
#         0.60154586],
#        [0.57624097, 0.21187952, 0.57624097, 0.57624097, 0.57624097,
#         0.60304872]])

# %%
res_acc = grid_search_results.mean(axis=1)[:,0]
res_hamm = grid_search_results.mean(axis=1)[:,1]
res_prec = grid_search_results.mean(axis=1)[:,2]
res_sens = grid_search_results.mean(axis=1)[:,3]
res_f1 = grid_search_results.mean(axis=1)[:,4]
res_aps = grid_search_results.mean(axis=1)[:,5]

# %%
rank_acc = (-res_acc).argsort()
rank_hamm = (res_hamm).argsort()
rank_prec = (-res_prec).argsort()
rank_sens = (-res_sens).argsort()
rank_f1 = (-res_f1).argsort()
rank_aps = (-res_aps).argsort()

# %%
rank_sums = np.array([np.where(rank_acc == i)[0][0] +
             np.where(rank_hamm == i)[0][0] +
            #  np.where(rank_prec == i)[0][0] +
            #  np.where(rank_sens == i)[0][0] +
            #  np.where(rank_f1 == i)[0][0] +
             np.where(rank_aps == i)[0][0]
              for i in range(rank_acc.shape[0])])



print(rank_sums[:90][45:][15:30][:5])
print(rank_sums[:90][45:][15:30][5:10])
print(rank_sums[:90][45:][15:30][10:])
print(rank_sums[:90][45:][30:][:5])
print(rank_sums[:90][45:][30:][5:10])
print(rank_sums[:90][45:][30:][10:])
print()
print()
# print(rank_sums)
# Out:
# [333  52  56 135 135]
# [238  54  90 116 159]
# [101  63  80 184 118]
# [447 165 275  84  56]
# [617 212 235  95  36]
# [438 204 237  55   3]

# %%
print(res_acc[61], res_hamm[61], res_aps[61])
print(res_acc[89], res_hamm[89], res_aps[89])
# Out:
# 0.5925971448880464 0.2037014275559768 0.6089536124431318
# 0.596953856178178 0.20152307191091104 0.6109228077296388

# %%
param_grid = {'num_hidden_layers': [0],
              'layer_size': [128],
              'lr': [0.002, 0.003],
              'weight_decay': [0.01],
              'batch_size': [48, 96],
              'BCE_weights_power': [0.5],
              'BCE_weights_factor': [1.2],
              'epochs': [20],
              'curvature': [-1]}

0.002, 48
0.003, 96+
# param_grid = {'num_hidden_layers': [0,1,2],
#               'layer_size': [64, 128],
#               'lr': [0.001, 0.002, 0.003],
#               'weight_decay': [0.001, 0.005, 0.01],
#               'batch_size': [32, 48, 64, 80, 96],
#               'BCE_weights_power': [0.5],
#               'BCE_weights_factor': [1.2],
#               'epochs': [20],
#               'curvature': [-1]}

# %%
grid_search_results = []
with open('grid_search_all.txt', 'r') as file:
    for line in file.readlines():
        if line[0:4] == '----':
            grid_search_results.append([])
            continue

        if line[0] == '(':
            params = ast.literal_eval(line)
            nested = [list(zip(key.split(','), np.array(val).flatten())) for (key, val) in params]
            unnested = [item for sublist in nested for item in sublist]
            grid_search_results[-1].append({key: val for (key, val) in unnested})
            continue

        if line[0:4] == 'Fold':
            grid_search_results[-1].append([])
            continue

        if result[0] == '[':
            grid_search_results[-1][-1].append(np.array(ast.literal_eval(result)).mean())
            continue

        grid_search_results[-1][-1].append(float(line.split('\t ')[1]))

grid_search_results = [(params, np.array([fd1, fd2, fd3, fd4, fd5]).mean(axis=0)) for (params, fd1, fd2, fd3, fd4, fd5) in grid_search_results]
# grid_search_results = np.array(grid_search_results)
# grid_search_results.shape

# %%
grid_search_results
# Out:
# [({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.07839368, 0.29219214, 0.57370791, 0.46126235])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.03863903, 0.33448244, 0.66740088, 0.46599431])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.01766738, 0.36713675, 0.71054298, 0.45833707])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08004657, 0.30032571, 0.58783675, 0.46114133])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.02594706, 0.35041757, 0.69399309, 0.46423788])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.01214556, 0.40555182, 0.74259188, 0.44455739])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.05188804, 0.32541154, 0.62730798, 0.45735939])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.01821378, 0.38606956, 0.71717934, 0.4485072 ])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.00827968, 0.45707502, 0.77195486, 0.425083  ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08283792, 0.28933295, 0.58334503, 0.46881443])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.05633228, 0.3252239 , 0.67656905, 0.47625214])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.04030866, 0.37737416, 0.73533184, 0.45974969])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.04417302, 0.35985811, 0.70339872, 0.4608942 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.02926503, 0.39591604, 0.75701513, 0.45523097])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.05687412, 0.33083573, 0.63634265, 0.45675594])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.03257994, 0.38282118, 0.72167904, 0.45172036])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.01711642, 0.42208858, 0.76839125, 0.44335739])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.14963548, 0.25218918, 0.45504483, 0.44098669])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 48,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.16508379, 0.25290604, 0.45667032, 0.44072786])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.16512184, 0.24997054, 0.46716364, 0.44948915])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.14466919, 0.26331479, 0.45879293, 0.43200112])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 48,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.14798107, 0.25763446, 0.47021266, 0.44357116])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.15956958, 0.25321697, 0.48211217, 0.45417767])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 80,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.14355813, 0.26141859, 0.46878181, 0.43940327])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 96,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.14961417, 0.25866464, 0.45564822, 0.43499596])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 80,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.13858271, 0.26244964, 0.48585453, 0.44758762])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 96,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.128122  , 0.26582935, 0.47401573, 0.43766718])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13637581, 0.26355287, 0.46181413, 0.4336184 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15348766, 0.25566456, 0.48358674, 0.45150742])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14522625, 0.26331218, 0.49419172, 0.45064718])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13860098, 0.25928736, 0.44399075, 0.42799469])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11816508, 0.27435799, 0.47028323, 0.42835884])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14355965, 0.2576349 , 0.4919323 , 0.45512564])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12478121, 0.26031123, 0.49788768, 0.45522179])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11983471, 0.27450127, 0.47239216, 0.42934481])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13693895, 0.26448955, 0.51445909, 0.45959786])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12200508, 0.26308127, 0.484008  , 0.44541838])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12920871, 0.2694641 , 0.45935199, 0.42687207])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14411975, 0.26780512, 0.46261293, 0.42954587])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.1269805 , 0.26679191, 0.45391161, 0.42626769])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12699268, 0.27041688, 0.45451833, 0.42323616])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15016362, 0.25329915, 0.47666783, 0.45110564])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11429311, 0.27348305, 0.45599217, 0.42147491])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11649392, 0.27380855, 0.4696152 , 0.42842788])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13085399, 0.26749137, 0.50011271, 0.44935872])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13858576, 0.26694563, 0.46793042, 0.43353695])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12866384, 0.2701714 , 0.47439677, 0.43412085])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15183477, 0.25692739, 0.48390268, 0.45121462])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.10325404, 0.27483633, 0.48373452, 0.43456537])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11539504, 0.27018184, 0.46151347, 0.42787282])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14687762, 0.26536318, 0.47350117, 0.4378331 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15348766, 0.25566456, 0.48358674, 0.45150742])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 48,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.10821728, 0.27830714, 0.49826355, 0.43865517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14522625, 0.26331218, 0.49419172, 0.45064718])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11816508, 0.27435799, 0.47028323, 0.42835884])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 48,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.10214906, 0.27988133, 0.51122006, 0.44391963])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14355965, 0.2576349 , 0.4919323 , 0.45512564])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.0035,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11649088, 0.2677362 , 0.47862622, 0.43863629])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.0035,
#    'weight_decay': 0,
#    'batch_size': 48,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.1153859 , 0.27191909, 0.49331209, 0.44192852])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.0035,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12313593, 0.26733352, 0.50540095, 0.45245242])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.0035,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11816508, 0.27325693, 0.4441414 , 0.41472802])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.0035,
#    'weight_decay': 0.0001,
#    'batch_size': 48,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.10378522, 0.278707  , 0.50101211, 0.43997832])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.0035,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12369146, 0.27277793, 0.50699315, 0.44823209])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02153783, 0.32965227, 0.59153209, 0.43908297])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.0287095 , 0.32011411, 0.56868175, 0.43642282])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02153783, 0.32965227, 0.59153209, 0.43908297])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.0287095 , 0.32011411, 0.56868175, 0.43642282])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02153783, 0.32965227, 0.59153209, 0.43908297])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.0287095 , 0.32011411, 0.56868175, 0.43642282])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02153783, 0.32965227, 0.59153209, 0.43908297])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.0287095 , 0.32011411, 0.56868175, 0.43642282])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02153783, 0.32965227, 0.59153209, 0.43908297])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.0287095 , 0.32011411, 0.56868175, 0.43642282])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02153783, 0.32965227, 0.59153209, 0.43908297])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.0287095 , 0.32011411, 0.56868175, 0.43642282])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02153783, 0.32965227, 0.59153209, 0.43908297])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.0287095 , 0.32011411, 0.56868175, 0.43642282])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02153783, 0.32965227, 0.59153209, 0.43908297])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.0287095 , 0.32011411, 0.56868175, 0.43642282])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02153783, 0.32965227, 0.59153209, 0.43908297])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.0287095 , 0.32011411, 0.56868175, 0.43642282])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02595315, 0.33289043, 0.59956447, 0.43971556])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02595315, 0.33289043, 0.59956447, 0.43971556])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02595315, 0.33289043, 0.59956447, 0.43971556])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02595315, 0.33289043, 0.59956447, 0.43971556])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02595315, 0.33289043, 0.59956447, 0.43971556])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02595315, 0.33289043, 0.59956447, 0.43971556])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02595315, 0.33289043, 0.59956447, 0.43971556])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02595315, 0.33289043, 0.59956447, 0.43971556])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02595315, 0.33289043, 0.59956447, 0.43971556])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
# ...
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.11871147, 0.28919053, 0.58370296, 0.46846792])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.11871147, 0.28919053, 0.58370296, 0.46846792])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.11871147, 0.28919053, 0.58370296, 0.46846792])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15348766, 0.25566456, 0.48358674, 0.45150742])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14522625, 0.26331218, 0.49419172, 0.45064718])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13748231, 0.2614973 , 0.52919315, 0.46811404])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11816508, 0.27435799, 0.47028323, 0.42835884])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14355965, 0.2576349 , 0.4919323 , 0.45512564])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13526475, 0.26063759, 0.52660898, 0.46842013])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12202335, 0.26307975, 0.44921946, 0.42677828])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.10655221, 0.27878462, 0.48495655, 0.43214502])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11208164, 0.27475284, 0.48694031, 0.43644104])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.1065857 , 0.27490112, 0.46280101, 0.42256687])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11152915, 0.26867592, 0.47053362, 0.43289725])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.10658874, 0.28104674, 0.49869919, 0.43650851])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.04086115, 0.30953946, 0.49591625, 0.41120882])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.07951692, 0.28697146, 0.49975462, 0.43222095])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.09552988, 0.26891444, 0.44974626, 0.42220868])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.06682495, 0.28997502, 0.46461128, 0.41165404])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.10050835, 0.27640247, 0.4726977 , 0.42641201])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.04196612, 0.30298856, 0.50138443, 0.41875347])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0579867 , 0.29919704, 0.49712915, 0.4188673 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.05798822, 0.29525375, 0.41357089, 0.37342815])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.05798822, 0.29525375, 0.41357089, 0.37342815])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.05798822, 0.29525375, 0.41357089, 0.37342815])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.05798822, 0.29525375, 0.41357089, 0.37342815])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.01,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.01,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.01,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.01,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.01,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.01,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187]))]

# %%
sorted(grid_search_results, key=lambda x: -x[1][3])
# Out:
# [({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.05633228, 0.3252239 , 0.67656905, 0.47625214])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14190372, 0.25479267, 0.52407953, 0.47346049])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15239639, 0.25290104, 0.51845695, 0.47253441])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03368187, 0.31379411, 0.64119909, 0.47148594])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08283792, 0.28933295, 0.58334503, 0.46881443])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.001,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.11871147, 0.28919053, 0.58370296, 0.46846792])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.11871147, 0.28919053, 0.58370296, 0.46846792])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.11871147, 0.28919053, 0.58370296, 0.46846792])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.11871147, 0.28919053, 0.58370296, 0.46846792])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.11871147, 0.28919053, 0.58370296, 0.46846792])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.11871147, 0.28919053, 0.58370296, 0.46846792])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13526475, 0.26063759, 0.52660898, 0.46842013])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13748231, 0.2614973 , 0.52919315, 0.46811404])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03810024, 0.31189922, 0.62651327, 0.46749497])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.03863903, 0.33448244, 0.66740088, 0.46599431])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04748033, 0.30393915, 0.60700642, 0.46591403])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.001,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.10932378, 0.29273114, 0.58376695, 0.46560599])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.10932378, 0.29273114, 0.58376695, 0.46560599])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.10932378, 0.29273114, 0.58376695, 0.46560599])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.10932378, 0.29273114, 0.58376695, 0.46560599])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.10932378, 0.29273114, 0.58376695, 0.46560599])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.10932378, 0.29273114, 0.58376695, 0.46560599])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04417454, 0.31078729, 0.61813242, 0.4650853 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.001,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08448777, 0.29903592, 0.59350036, 0.46463488])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.02594706, 0.35041757, 0.69399309, 0.46423788])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04584266, 0.31323466, 0.62144251, 0.46423644])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04584266, 0.31323466, 0.62144251, 0.46423644])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04584266, 0.31323466, 0.62144251, 0.46423644])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04584266, 0.31323466, 0.62144251, 0.46423644])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04584266, 0.31323466, 0.62144251, 0.46423644])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04584266, 0.31323466, 0.62144251, 0.46423644])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04584266, 0.31323466, 0.62144251, 0.46423644])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04584266, 0.31323466, 0.62144251, 0.46423644])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.04584266, 0.31323466, 0.62144251, 0.46423644])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.0386512 , 0.31308594, 0.61623453, 0.46222971])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.07839368, 0.29219214, 0.57370791, 0.46126235])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08004657, 0.30032571, 0.58783675, 0.46114133])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.001,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08004657, 0.30032571, 0.58783675, 0.46114133])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08004657, 0.30032571, 0.58783675, 0.46114133])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08004657, 0.30032571, 0.58783675, 0.46114133])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 16,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08004657, 0.30032571, 0.58783675, 0.46114133])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 32,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08004657, 0.30032571, 0.58783675, 0.46114133])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.08004657, 0.30032571, 0.58783675, 0.46114133])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.04417302, 0.35985811, 0.70339872, 0.4608942 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.04030866, 0.37737416, 0.73533184, 0.45974969])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13693895, 0.26448955, 0.51445909, 0.45959786])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.01766738, 0.36713675, 0.71054298, 0.45833707])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.05188804, 0.32541154, 0.62730798, 0.45735939])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.04307718, 0.31631715, 0.60981867, 0.45728517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.04307718, 0.31631715, 0.60981867, 0.45728517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.04307718, 0.31631715, 0.60981867, 0.45728517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.04307718, 0.31631715, 0.60981867, 0.45728517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.04307718, 0.31631715, 0.60981867, 0.45728517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.04307718, 0.31631715, 0.60981867, 0.45728517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.04307718, 0.31631715, 0.60981867, 0.45728517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.04307718, 0.31631715, 0.60981867, 0.45728517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.04307718, 0.31631715, 0.60981867, 0.45728517])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.01,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.01,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.01,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.01,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.01,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.01,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0640473 , 0.27923709, 0.53837482, 0.45712187])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03976531, 0.31102581, 0.60009409, 0.45701271])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.05687412, 0.33083573, 0.63634265, 0.45675594])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.03424806, 0.31575075, 0.60859597, 0.4566965 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.02926503, 0.39591604, 0.75701513, 0.45523097])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12478121, 0.26031123, 0.49788768, 0.45522179])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14355965, 0.2576349 , 0.4919323 , 0.45512564])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14355965, 0.2576349 , 0.4919323 , 0.45512564])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14355965, 0.2576349 , 0.4919323 , 0.45512564])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.15956958, 0.25321697, 0.48211217, 0.45417767])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11541026, 0.2685109 , 0.51186895, 0.45394897])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03147345, 0.31371866, 0.59635002, 0.45348786])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 128,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02926503, 0.3148993 , 0.59662347, 0.45272616])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.0035,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12313593, 0.26733352, 0.50540095, 0.45245242])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.03257994, 0.38282118, 0.72167904, 0.45172036])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15348766, 0.25566456, 0.48358674, 0.45150742])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15348766, 0.25566456, 0.48358674, 0.45150742])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15348766, 0.25566456, 0.48358674, 0.45150742])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15183477, 0.25692739, 0.48390268, 0.45121462])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.15016362, 0.25329915, 0.47666783, 0.45110564])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14522625, 0.26331218, 0.49419172, 0.45064718])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14522625, 0.26331218, 0.49419172, 0.45064718])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14522625, 0.26331218, 0.49419172, 0.45064718])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.16512184, 0.24997054, 0.46716364, 0.44948915])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13085399, 0.26749137, 0.50011271, 0.44935872])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.01821378, 0.38606956, 0.71717934, 0.4485072 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.0035,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12369146, 0.27277793, 0.50699315, 0.44823209])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 80,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.13858271, 0.26244964, 0.48585453, 0.44758762])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12200508, 0.26308127, 0.484008  , 0.44541838])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
#  ({'num_hidden_layers': 0,
#    'layer_size': 256,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.03590095, 0.31568074, 0.58180981, 0.44527069])),
# ...
#   array([0.07951692, 0.28697146, 0.49975462, 0.43222095])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.10655221, 0.27878462, 0.48495655, 0.43214502])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 400,
#    'curvature': -1},
#   array([0.14466919, 0.26331479, 0.45879293, 0.43200112])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -1},
#   array([0.02926198, 0.31861428, 0.55475132, 0.43171938])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.14411975, 0.26780512, 0.46261293, 0.42954587])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11983471, 0.27450127, 0.47239216, 0.42934481])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11649392, 0.27380855, 0.4696152 , 0.42842788])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02595315, 0.33131538, 0.57114059, 0.42836605])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11816508, 0.27435799, 0.47028323, 0.42835884])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11816508, 0.27435799, 0.47028323, 0.42835884])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11816508, 0.27435799, 0.47028323, 0.42835884])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.13860098, 0.25928736, 0.44399075, 0.42799469])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.65,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 1.6,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 64,
#    'lr': 0.003,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 100,
#    'curvature': -2},
#   array([0.02815397, 0.32485122, 0.56220806, 0.42787622])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11539504, 0.27018184, 0.46151347, 0.42787282])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 384,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12920871, 0.2694641 , 0.45935199, 0.42687207])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12202335, 0.26307975, 0.44921946, 0.42677828])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.10050835, 0.27640247, 0.4726977 , 0.42641201])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.1269805 , 0.26679191, 0.45391161, 0.42626769])),
#  ({'num_hidden_layers': 1,
#    'layer_size': 128,
#    'lr': 0.002,
#    'batch_size': 64,
#    'BCE_weights_power': 0.8,
#    'BCE_weights_factor': 2,
#    'epochs': 200,
#    'curvature': -1},
#   array([0.00827968, 0.45707502, 0.77195486, 0.425083  ])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.12699268, 0.27041688, 0.45451833, 0.42323616])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.005,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.1065857 , 0.27490112, 0.46280101, 0.42256687])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.09552988, 0.26891444, 0.44974626, 0.42220868])),
#  ({'num_hidden_layers': 3,
#    'layer_size': 256,
#    'lr': 0.003,
#    'weight_decay': 0.0001,
#    'batch_size': 24,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11429311, 0.27348305, 0.45599217, 0.42147491])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.0579867 , 0.29919704, 0.49712915, 0.4188673 ])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.04196612, 0.30298856, 0.50138443, 0.41875347])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.0035,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.11816508, 0.27325693, 0.4441414 , 0.41472802])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.06682495, 0.28997502, 0.46461128, 0.41165404])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.04086115, 0.30953946, 0.49591625, 0.41120882])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.01,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.02,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0.0001,
#    'batch_size': 128,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.03975618, 0.30188358, 0.46294922, 0.40130375])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.05798822, 0.29525375, 0.41357089, 0.37342815])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.05798822, 0.29525375, 0.41357089, 0.37342815])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0.0001,
#    'batch_size': 32,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.05798822, 0.29525375, 0.41357089, 0.37342815])),
#  ({'num_hidden_layers': 2,
#    'layer_size': 256,
#    'lr': 0.05,
#    'weight_decay': 0.0001,
#    'batch_size': 64,
#    'BCE_weights_power': 0.5,
#    'BCE_weights_factor': 1.2,
#    'epochs': 250,
#    'curvature': -1},
#   array([0.05798822, 0.29525375, 0.41357089, 0.37342815]))]
